# %%
import os
import re
import numpy as np
import pandas as pd

# %% [markdown]
# # Extract Featurres from README

# %%
def extract_metadata_from_readme(readme_path):
    """Extracts metadata fields from a README file."""
    metadata = {
        "gender": None,
        "age_range": None,
        "language": None,
        "dialect": None,
    }

    with open(readme_path, "r", encoding="utf-8", errors="ignore") as f:
        content = f.read()

    # Basic regex extraction
    gender_match = re.search(r"Gender:\s*(\w+)", content, re.IGNORECASE)
    age_match = re.search(r"Age Range:\s*([^\n\r]+)", content, re.IGNORECASE)
    lang_match = re.search(r"Language:\s*(\w+)", content, re.IGNORECASE)
    dialect_match = re.search(r"Pronunciation dialect:\s*([^\n\r]+)", content, re.IGNORECASE)

    if gender_match:
        metadata["gender"] = gender_match.group(1).strip()
    if age_match:
        metadata["age_range"] = age_match.group(1).strip()
    if lang_match:
        metadata["language"] = lang_match.group(1).strip()
    if dialect_match:
        metadata["dialect"] = dialect_match.group(1).strip()

    return metadata

# %% [markdown]
# # Merge DF

# %%
def build_metadata_dataframe(extract_dir):
    rows = []

    for root, dirs, files in os.walk(extract_dir):
        if "etc" in root and "README" in files:
            readme_path = os.path.join(root, "README")
            metadata = extract_metadata_from_readme(readme_path)

            # Get corresponding wav directory
            wav_dir = root.replace("/etc", "/wav")
            if not os.path.exists(wav_dir):
                continue

            for wav_file in os.listdir(wav_dir):
                if wav_file.endswith(".wav"):
                    full_path = os.path.join(wav_dir, wav_file)
                    rel_path = os.path.relpath(full_path, extract_dir)

                    rows.append({
                        "filename": rel_path,
                        **{k: v.lower() if isinstance(v, str) else v for k, v in metadata.items()}
                    })

    return pd.DataFrame(rows)

# %%
features_df = pd.read_parquet("voxforge_data/audio_features.parquet")
metadata_df = build_metadata_dataframe("voxforge_data/extracted")

# %%
features_df
# Out:
#                                   filename  mean_freq_kHz  std_freq_kHz  \
# 0      robin-20070310-vf12/wav/vf12-34.wav       3.999961      2.309424
# 1      robin-20070310-vf12/wav/vf12-29.wav       4.000000      2.309454
# 2      robin-20070310-vf12/wav/vf12-24.wav       4.000000      2.309442
# 3      robin-20070310-vf12/wav/vf12-06.wav       4.000000      2.309460
# 4      robin-20070310-vf12/wav/vf12-38.wav       3.999964      2.309422
# ...                                    ...            ...           ...
# 69033      Luis-20130226-peg/wav/b0325.wav       4.000000      2.309476
# 69034      Luis-20130226-peg/wav/b0323.wav       4.000000      2.309447
# 69035      Luis-20130226-peg/wav/b0329.wav       4.000000      2.309484
# 69036      Luis-20130226-peg/wav/b0327.wav       4.000000      2.309497
# 69037      Luis-20130226-peg/wav/b0322.wav       4.000000      2.309469
#
#        median_freq_kHz  first_quantile_kHz  third_quantile_kHz   iqr_kHz  \
# 0             3.999961            1.999981            5.999942  3.999961
# 1             4.000000            2.000000            6.000000  4.000000
# 2             4.000000            2.000000            6.000000  4.000000
# 3             4.000000            2.000000            6.000000  4.000000
# 4             3.999964            1.999982            5.999946  3.999964
# ...                ...                 ...                 ...       ...
# 69033         4.000000            2.000000            6.000000  4.000000
# 69034         4.000000            2.000000            6.000000  4.000000
# 69035         4.000000            2.000000            6.000000  4.000000
# 69036         4.000000            2.000000            6.000000  4.000000
# 69037         4.000000            2.000000            6.000000  4.000000
#
#        skewness   kurtosis  mode_freq_kHz  peak_freq_kHz  sp_entropy  \
# 0      4.289625  22.129724       0.596192       0.596192   13.797732
# 1      4.468912  24.387798       0.518989       0.518989   13.671813
# 2      4.768208  28.682903       0.522362       0.522362   13.983390
# 3      4.288241  22.928845       0.165990       0.165990   13.383058
# 4      4.437734  23.512740       0.327474       0.327474   14.031024
# ...         ...        ...            ...            ...         ...
# 69033  8.821168  99.341927       0.127484       0.127484   12.227013
# 69034  7.781451  82.411050       0.121120       0.121120   12.875872
# 69035  8.237866  97.468529       0.143143       0.143143   12.128605
# 69036  8.133196  93.356766       0.117333       0.117333   11.977746
# 69037  6.112829  49.885702       0.121176       0.121176   12.441242
#
#        flatness  centroid_kHz   modindx
# 0      0.131873      1.104101  2.316162
# 1      0.145211      1.173674  2.266816
# 2      0.154861      1.182493  2.340302
# 3      0.113975      1.056596  2.309039
# 4      0.154637      1.212154  2.255088
# ...         ...           ...       ...
# 69033  0.186738      0.926109  3.981581
# 69034  0.149606      0.784108  3.738265
# 69035  0.123457      0.790771  3.505875
# 69036  0.152190      0.854203  3.538266
# 69037  0.121413      0.808310  3.262896
#
# [69038 rows x 15 columns]

# %%
metadata_df
# Out:
#                                   filename gender age_range language  \
# 0      robin-20070310-vf12/wav/vf12-34.wav   male    adult;     None
# 1      robin-20070310-vf12/wav/vf12-29.wav   male    adult;     None
# 2      robin-20070310-vf12/wav/vf12-24.wav   male    adult;     None
# 3      robin-20070310-vf12/wav/vf12-06.wav   male    adult;     None
# 4      robin-20070310-vf12/wav/vf12-38.wav   male    adult;     None
# ...                                    ...    ...       ...      ...
# 83653      Luis-20130226-peg/wav/b0325.wav   male     adult       en
# 83654      Luis-20130226-peg/wav/b0323.wav   male     adult       en
# 83655      Luis-20130226-peg/wav/b0329.wav   male     adult       en
# 83656      Luis-20130226-peg/wav/b0327.wav   male     adult       en
# 83657      Luis-20130226-peg/wav/b0322.wav   male     adult       en
#
#                                          dialect
# 0      british english (mother tongue is dutch).
# 1      british english (mother tongue is dutch).
# 2      british english (mother tongue is dutch).
# 3      british english (mother tongue is dutch).
# 4      british english (mother tongue is dutch).
# ...                                          ...
# 83653                           european english
# 83654                           european english
# 83655                           european english
# 83656                           european english
# 83657                           european english
#
# [83658 rows x 5 columns]

# %%
merged_df = features_df.merge(metadata_df, on="filename", how="inner")

# %%
merged_df
# Out:
#                                   filename  mean_freq_kHz  std_freq_kHz  \
# 0      robin-20070310-vf12/wav/vf12-34.wav       3.999961      2.309424
# 1      robin-20070310-vf12/wav/vf12-29.wav       4.000000      2.309454
# 2      robin-20070310-vf12/wav/vf12-24.wav       4.000000      2.309442
# 3      robin-20070310-vf12/wav/vf12-06.wav       4.000000      2.309460
# 4      robin-20070310-vf12/wav/vf12-38.wav       3.999964      2.309422
# ...                                    ...            ...           ...
# 66081      Luis-20130226-peg/wav/b0325.wav       4.000000      2.309476
# 66082      Luis-20130226-peg/wav/b0323.wav       4.000000      2.309447
# 66083      Luis-20130226-peg/wav/b0329.wav       4.000000      2.309484
# 66084      Luis-20130226-peg/wav/b0327.wav       4.000000      2.309497
# 66085      Luis-20130226-peg/wav/b0322.wav       4.000000      2.309469
#
#        median_freq_kHz  first_quantile_kHz  third_quantile_kHz   iqr_kHz  \
# 0             3.999961            1.999981            5.999942  3.999961
# 1             4.000000            2.000000            6.000000  4.000000
# 2             4.000000            2.000000            6.000000  4.000000
# 3             4.000000            2.000000            6.000000  4.000000
# 4             3.999964            1.999982            5.999946  3.999964
# ...                ...                 ...                 ...       ...
# 66081         4.000000            2.000000            6.000000  4.000000
# 66082         4.000000            2.000000            6.000000  4.000000
# 66083         4.000000            2.000000            6.000000  4.000000
# 66084         4.000000            2.000000            6.000000  4.000000
# 66085         4.000000            2.000000            6.000000  4.000000
#
#        skewness   kurtosis  mode_freq_kHz  peak_freq_kHz  sp_entropy  \
# 0      4.289625  22.129724       0.596192       0.596192   13.797732
# 1      4.468912  24.387798       0.518989       0.518989   13.671813
# 2      4.768208  28.682903       0.522362       0.522362   13.983390
# 3      4.288241  22.928845       0.165990       0.165990   13.383058
# 4      4.437734  23.512740       0.327474       0.327474   14.031024
# ...         ...        ...            ...            ...         ...
# 66081  8.821168  99.341927       0.127484       0.127484   12.227013
# 66082  7.781451  82.411050       0.121120       0.121120   12.875872
# 66083  8.237866  97.468529       0.143143       0.143143   12.128605
# 66084  8.133196  93.356766       0.117333       0.117333   11.977746
# 66085  6.112829  49.885702       0.121176       0.121176   12.441242
#
#        flatness  centroid_kHz   modindx gender age_range language  \
# 0      0.131873      1.104101  2.316162   male    adult;     None
# 1      0.145211      1.173674  2.266816   male    adult;     None
# 2      0.154861      1.182493  2.340302   male    adult;     None
# 3      0.113975      1.056596  2.309039   male    adult;     None
# 4      0.154637      1.212154  2.255088   male    adult;     None
# ...         ...           ...       ...    ...       ...      ...
# 66081  0.186738      0.926109  3.981581   male     adult       en
# 66082  0.149606      0.784108  3.738265   male     adult       en
# 66083  0.123457      0.790771  3.505875   male     adult       en
# 66084  0.152190      0.854203  3.538266   male     adult       en
# 66085  0.121413      0.808310  3.262896   male     adult       en
#
#                                          dialect
# 0      british english (mother tongue is dutch).
# 1      british english (mother tongue is dutch).
# 2      british english (mother tongue is dutch).
# 3      british english (mother tongue is dutch).
# 4      british english (mother tongue is dutch).
# ...                                          ...
# 66081                           european english
# 66082                           european english
# 66083                           european english
# 66084                           european english
# 66085                           european english
#
# [66086 rows x 19 columns]

# %%
merged_df['age_range'].unique()
# Out:
# array(['adult;', 'adult', 'youth', 'please select', '[adult];', 'senior',
#        'unknown', 'erwachsener', 'senior;', 'adulto', None, 'jeune',
#        'adult (born in 1983)', '[youth];', 'male', 'youth;'], dtype=object)

# %% [markdown]
# # Remapping Age and Gender

# %%
merged_df["age_range"] = (
    merged_df["age_range"]
    .str.lower()
    .str.replace(";", "", regex=False)
    .str.strip()
    .replace({
        "erwachsener": "adult",
        "adulto": "adult",
        "adulte": "adult",
        "adult (born in 1983)": "adult",
        "[adult]": "adult",
        "[adult]": "adult",
        "youth;": "youth",
        "[youth]": "youth",
        "jeune": "youth",
        "senior;": "senior",
        "please select": "unknown",
        None: "unknown",
        "male": "unknown"  
    })
    .fillna("unknown")
)

# %%
merged_df["age_range"].value_counts()
# Out:
# age_range
# adult      51394
# unknown     7037
# youth       6282
# senior      1373
# Name: count, dtype: int64

# %%
merged_df['language'].unique()
# Out:
# array([None, 'en'], dtype=object)

# %%
merged_df['gender'].unique()
# Out:
# array(['male', 'female', 'please', None, 'unknown', 'männlich',
#        'masculino', 'masculin', 'adult', 'weiblich', 'make'], dtype=object)

# %%
gender_map = {
    'male': 'male',
    'make': 'male',
    'männlich': 'male',
    'masculino': 'male',
    'masculin': 'male',
    'female': 'female',
    'weiblich': 'female'
}

merged_df['gender'] = merged_df['gender'].map(gender_map)

merged_df = merged_df[merged_df['gender'].isin(['male', 'female'])]

# %%
en_merged_df = merged_df[merged_df['dialect'].str.contains('english', case=False, na=False)]

# %%
en_merged_df = en_merged_df.drop(columns=['dialect'])
en_merged_df = en_merged_df.drop(columns=['language'])
en_merged_df
# Out:
#                                   filename  mean_freq_kHz  std_freq_kHz  \
# 0      robin-20070310-vf12/wav/vf12-34.wav       3.999961      2.309424
# 1      robin-20070310-vf12/wav/vf12-29.wav       4.000000      2.309454
# 2      robin-20070310-vf12/wav/vf12-24.wav       4.000000      2.309442
# 3      robin-20070310-vf12/wav/vf12-06.wav       4.000000      2.309460
# 4      robin-20070310-vf12/wav/vf12-38.wav       3.999964      2.309422
# ...                                    ...            ...           ...
# 66081      Luis-20130226-peg/wav/b0325.wav       4.000000      2.309476
# 66082      Luis-20130226-peg/wav/b0323.wav       4.000000      2.309447
# 66083      Luis-20130226-peg/wav/b0329.wav       4.000000      2.309484
# 66084      Luis-20130226-peg/wav/b0327.wav       4.000000      2.309497
# 66085      Luis-20130226-peg/wav/b0322.wav       4.000000      2.309469
#
#        median_freq_kHz  first_quantile_kHz  third_quantile_kHz   iqr_kHz  \
# 0             3.999961            1.999981            5.999942  3.999961
# 1             4.000000            2.000000            6.000000  4.000000
# 2             4.000000            2.000000            6.000000  4.000000
# 3             4.000000            2.000000            6.000000  4.000000
# 4             3.999964            1.999982            5.999946  3.999964
# ...                ...                 ...                 ...       ...
# 66081         4.000000            2.000000            6.000000  4.000000
# 66082         4.000000            2.000000            6.000000  4.000000
# 66083         4.000000            2.000000            6.000000  4.000000
# 66084         4.000000            2.000000            6.000000  4.000000
# 66085         4.000000            2.000000            6.000000  4.000000
#
#        skewness   kurtosis  mode_freq_kHz  peak_freq_kHz  sp_entropy  \
# 0      4.289625  22.129724       0.596192       0.596192   13.797732
# 1      4.468912  24.387798       0.518989       0.518989   13.671813
# 2      4.768208  28.682903       0.522362       0.522362   13.983390
# 3      4.288241  22.928845       0.165990       0.165990   13.383058
# 4      4.437734  23.512740       0.327474       0.327474   14.031024
# ...         ...        ...            ...            ...         ...
# 66081  8.821168  99.341927       0.127484       0.127484   12.227013
# 66082  7.781451  82.411050       0.121120       0.121120   12.875872
# 66083  8.237866  97.468529       0.143143       0.143143   12.128605
# 66084  8.133196  93.356766       0.117333       0.117333   11.977746
# 66085  6.112829  49.885702       0.121176       0.121176   12.441242
#
#        flatness  centroid_kHz   modindx gender age_range
# 0      0.131873      1.104101  2.316162   male     adult
# 1      0.145211      1.173674  2.266816   male     adult
# 2      0.154861      1.182493  2.340302   male     adult
# 3      0.113975      1.056596  2.309039   male     adult
# 4      0.154637      1.212154  2.255088   male     adult
# ...         ...           ...       ...    ...       ...
# 66081  0.186738      0.926109  3.981581   male     adult
# 66082  0.149606      0.784108  3.738265   male     adult
# 66083  0.123457      0.790771  3.505875   male     adult
# 66084  0.152190      0.854203  3.538266   male     adult
# 66085  0.121413      0.808310  3.262896   male     adult
#
# [45295 rows x 17 columns]

# %% [markdown]
# # Dropping Non-English Dialect

# %%
en_merged_df = en_merged_df.dropna()

en_merged_df = en_merged_df.drop_duplicates(subset=["filename"])

# %%
en_merged_df
# Out:
#                                   filename  mean_freq_kHz  std_freq_kHz  \
# 0      robin-20070310-vf12/wav/vf12-34.wav       3.999961      2.309424
# 1      robin-20070310-vf12/wav/vf12-29.wav       4.000000      2.309454
# 2      robin-20070310-vf12/wav/vf12-24.wav       4.000000      2.309442
# 3      robin-20070310-vf12/wav/vf12-06.wav       4.000000      2.309460
# 4      robin-20070310-vf12/wav/vf12-38.wav       3.999964      2.309422
# ...                                    ...            ...           ...
# 66081      Luis-20130226-peg/wav/b0325.wav       4.000000      2.309476
# 66082      Luis-20130226-peg/wav/b0323.wav       4.000000      2.309447
# 66083      Luis-20130226-peg/wav/b0329.wav       4.000000      2.309484
# 66084      Luis-20130226-peg/wav/b0327.wav       4.000000      2.309497
# 66085      Luis-20130226-peg/wav/b0322.wav       4.000000      2.309469
#
#        median_freq_kHz  first_quantile_kHz  third_quantile_kHz   iqr_kHz  \
# 0             3.999961            1.999981            5.999942  3.999961
# 1             4.000000            2.000000            6.000000  4.000000
# 2             4.000000            2.000000            6.000000  4.000000
# 3             4.000000            2.000000            6.000000  4.000000
# 4             3.999964            1.999982            5.999946  3.999964
# ...                ...                 ...                 ...       ...
# 66081         4.000000            2.000000            6.000000  4.000000
# 66082         4.000000            2.000000            6.000000  4.000000
# 66083         4.000000            2.000000            6.000000  4.000000
# 66084         4.000000            2.000000            6.000000  4.000000
# 66085         4.000000            2.000000            6.000000  4.000000
#
#        skewness   kurtosis  mode_freq_kHz  peak_freq_kHz  sp_entropy  \
# 0      4.289625  22.129724       0.596192       0.596192   13.797732
# 1      4.468912  24.387798       0.518989       0.518989   13.671813
# 2      4.768208  28.682903       0.522362       0.522362   13.983390
# 3      4.288241  22.928845       0.165990       0.165990   13.383058
# 4      4.437734  23.512740       0.327474       0.327474   14.031024
# ...         ...        ...            ...            ...         ...
# 66081  8.821168  99.341927       0.127484       0.127484   12.227013
# 66082  7.781451  82.411050       0.121120       0.121120   12.875872
# 66083  8.237866  97.468529       0.143143       0.143143   12.128605
# 66084  8.133196  93.356766       0.117333       0.117333   11.977746
# 66085  6.112829  49.885702       0.121176       0.121176   12.441242
#
#        flatness  centroid_kHz   modindx gender age_range
# 0      0.131873      1.104101  2.316162   male     adult
# 1      0.145211      1.173674  2.266816   male     adult
# 2      0.154861      1.182493  2.340302   male     adult
# 3      0.113975      1.056596  2.309039   male     adult
# 4      0.154637      1.212154  2.255088   male     adult
# ...         ...           ...       ...    ...       ...
# 66081  0.186738      0.926109  3.981581   male     adult
# 66082  0.149606      0.784108  3.738265   male     adult
# 66083  0.123457      0.790771  3.505875   male     adult
# 66084  0.152190      0.854203  3.538266   male     adult
# 66085  0.121413      0.808310  3.262896   male     adult
#
# [45295 rows x 17 columns]

# %% [markdown]
# # Save DF as Parquet

# %%
# en_merged_df.to_parquet("en_merged_df.parquet", index=False)
# print("✅ Saved en_merged_df to datung/en_merged_df.parquet")
# Out:
# ✅ Saved en_merged_df to datung/en_merged_df.parquet
