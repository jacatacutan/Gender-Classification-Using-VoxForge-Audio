# %%
import os
import tarfile
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
import librosa
import numpy as np
import pandas as pd
from scipy import stats
import cupy as cp
from tqdm import tqdm

# %%
BASE_URL = "http://www.repository.voxforge1.org/downloads/SpeechCorpus/Trunk/Audio/Main/16kHz_16bit/"
DOWNLOAD_DIR = "voxforge_data"
EXTRACT_DIR = "voxforge_data/extracted"
RESULTS_FILE = "voxforge_data/results_summary.txt"
FEATURES_FILE = "voxforge_data/audio_features.parquet"

# %%
os.makedirs(DOWNLOAD_DIR, exist_ok=True)
os.makedirs(EXTRACT_DIR, exist_ok=True)

# %% [markdown]
# # Download & Extract

# %%
### 1. Get .tgz links from base URL
def get_tgz_links():
    response = requests.get(BASE_URL)
    if response.status_code != 200:
        print("Failed to retrieve webpage")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    pre_tag = soup.find("pre")
    if not pre_tag:
        print("Could not find the <pre> tag.")
        return []
    
    return [BASE_URL + a["href"] for a in pre_tag.find_all("a", href=True) if a["href"].endswith(".tgz")]

### 2. Download .tgz files in parallel
def download_tgz(url):
    filename = os.path.join(DOWNLOAD_DIR, url.split("/")[-1])
    if os.path.exists(filename):
        print(f"{filename} already exists, skipping download.")
        return filename

    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(filename, "wb") as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
        print(f"Downloaded {filename}")
        return filename
    print(f"Failed to download {url}")
    return None

def parallel_download_tgz():
    tgz_links = get_tgz_links()
    with ThreadPoolExecutor(max_workers=12) as executor:
        return list(executor.map(download_tgz, tgz_links))

### 3. Extract .tgz files in parallel
def extract_tgz(filepath):
    with tarfile.open(filepath, "r:gz") as tar:
        tar.extractall(path=EXTRACT_DIR)
    print(f"Extracted {filepath}")

def parallel_extract_tgz(tgz_files):
    with ThreadPoolExecutor(max_workers=8) as executor:
        executor.map(extract_tgz, tgz_files)
    print("All files extracted.")

### 4. Filter .wav files by human vocal range
def is_within_vocal_range(wav_path):
    y, sr = librosa.load(wav_path, sr=None)
    freqs = np.fft.rfftfreq(len(y), d=1/sr)
    spectrum = np.abs(np.fft.rfft(y))

    human_vocal_range = (0, 280)
    valid_freqs = freqs[(freqs >= human_vocal_range[0]) & (freqs <= human_vocal_range[1])]
    valid_spectrum = spectrum[:len(valid_freqs)]
    return valid_spectrum.any()

def get_vocal_range_wavs():
    
    """Parallelized version of get_vocal_range_wavs() with progress updates."""
    all_wavs = []
    for root, _, files in os.walk(EXTRACT_DIR):
        for file in files:
            if file.endswith(".wav"):
                all_wavs.append(os.path.join(root, file))

    print(f"Total .wav files found: {len(all_wavs)}")

    valid_wavs = []
    
    # Process in parallel with tqdm for real-time feedback
    with ProcessPoolExecutor(max_workers=10) as executor:
        results = list(tqdm(executor.map(is_within_vocal_range, all_wavs), total=len(all_wavs), desc="Filtering .wav files"))

    # Collect only the valid files
    valid_wavs = [wav for wav, valid in zip(all_wavs, results) if valid]

    print(f"\nFiltered to {len(valid_wavs)} .wav files within human vocal range.")
    print(f"Dropped files: {len(all_wavs) - len(valid_wavs)}")
    
    return valid_wavs

# %%
downloaded_tgz_files = parallel_download_tgz()
parallel_extract_tgz(downloaded_tgz_files)
# Out:
# voxforge_data/1028-20100710-hne.tgz already exists, skipping download.
# voxforge_data/1337ad-20170321-ajg.tgz already exists, skipping download.
# voxforge_data/1337ad-20170321-tkg.tgz already exists, skipping download.
# voxforge_data/1337ad-20170321-ynk.tgz already exists, skipping download.
# voxforge_data/1snoke-20120412-hge.tgz already exists, skipping download.
# voxforge_data/23yipikaye-20100807-ujm.tgz already exists, skipping download.
# voxforge_data/2old2play-20110606-hcn.tgz already exists, skipping download.
# voxforge_data/2old2play-20110606-wlt.tgz already exists, skipping download.
# voxforge_data/314piwm-20130617-xuo.tgz already exists, skipping download.
# voxforge_data/AJN-20131002-zcl.tgz already exists, skipping download.
# voxforge_data/AT-20130718-lws.tgz already exists, skipping download.
# voxforge_data/Aaron-20080318-kdl.tgz already exists, skipping download.
# voxforge_data/Aaron-20080318-lbb.tgz already exists, skipping download.
# voxforge_data/Aaron-20080318-lbk.tgz already exists, skipping download.
# voxforge_data/Aaron-20080318-liy.tgz already exists, skipping download.
# voxforge_data/Aaron-20080318-ngh.tgz already exists, skipping download.
# voxforge_data/Aaron-20080318-pwn.tgz already exists, skipping download.
# voxforge_data/Aaron-20130527-giy.tgz already exists, skipping download.
# voxforge_data/AbdulMoiz-20121010-juf.tgz already exists, skipping download.
# voxforge_data/Adminvox-05232006.tgz already exists, skipping download.
# voxforge_data/Adminvox-05262006.tgz already exists, skipping download.
# voxforge_data/AdrianMcNear-20091016-psv.tgz already exists, skipping download.
# voxforge_data/Afshad-20090813-zcz.tgz already exists, skipping download.
# voxforge_data/Afzal-20110524-qsu.tgz already exists, skipping download.
# voxforge_data/Airwings-20101216-vqx.tgz already exists, skipping download.
# voxforge_data/Airwings-20101216-zul.tgz already exists, skipping download.
# voxforge_data/Akhansson-20120423-yas.tgz already exists, skipping download.
# voxforge_data/Akram-20101102-qax.tgz already exists, skipping download.
# voxforge_data/AlexW-20110510-hzr.tgz already exists, skipping download.
# voxforge_data/AlexanderHenningDrachmann-20140108-dgf.tgz already exists, skipping download.
# voxforge_data/AlexanderHenningDrachmann-20140108-klh.tgz already exists, skipping download.
# voxforge_data/AlexanderHenningDrachmann-20140108-koe.tgz already exists, skipping download.
# voxforge_data/AlexanderHenningDrachmann-20140108-mme.tgz already exists, skipping download.
# voxforge_data/AlexanderHenningDrachmann-20140108-sju.tgz already exists, skipping download.
# voxforge_data/AlexanderHenningDrachmann-20140108-vgf.tgz already exists, skipping download.
# voxforge_data/AlexanderHenningDrachmann-20140108-vul.tgz already exists, skipping download.
# voxforge_data/AlfredStrauss-20110812-eza.tgz already exists, skipping download.
# voxforge_data/Alpsa-20100604-mzc.tgz already exists, skipping download.
# voxforge_data/AmolS-20140213-pvg.tgz already exists, skipping download.
# voxforge_data/Andrew-20120826-wzg.tgz already exists, skipping download.
# voxforge_data/AndreyBarrientosCostaRica-20130709-ukl.tgz already exists, skipping download.
# voxforge_data/AndreyBarrientosCostaRica-20130710-oqe.tgz already exists, skipping download.
# voxforge_data/AndreyBarrientosCostaRica-20130710-tpy.tgz already exists, skipping download.
# voxforge_data/AndreyBarrientosCostaRica-20130720-pxz.tgz already exists, skipping download.
# voxforge_data/Andy212380-20141016-lzl.tgz already exists, skipping download.
# voxforge_data/Angus-20080320-cjg.tgz already exists, skipping download.
# voxforge_data/Angus-20080320-mih.tgz already exists, skipping download.
# voxforge_data/Angus-20080320-ndd.tgz already exists, skipping download.
# voxforge_data/Angus-20080320-sdh.tgz already exists, skipping download.
# voxforge_data/AnnaKarpelevich-20091129-til.tgz already exists, skipping download.
# voxforge_data/Anniepoo-20140308-bft.tgz already exists, skipping download.
# voxforge_data/Anniepoo-20140308-byi.tgz already exists, skipping download.
# voxforge_data/Anniepoo-20140308-cqj.tgz already exists, skipping download.
# voxforge_data/Anniepoo-20140308-fcp.tgz already exists, skipping download.
# voxforge_data/Anniepoo-20140308-hns.tgz already exists, skipping download.
# voxforge_data/Anniepoo-20140308-nky.tgz already exists, skipping download.
# voxforge_data/Anniepoo-20140308-xot.tgz already exists, skipping download.
# voxforge_data/Anniepoo-20140308-zwy.tgz already exists, skipping download.
# voxforge_data/Apple_Eater-20091026-yul.tgz already exists, skipping download.
# voxforge_data/Ara-20091020-vni.tgz already exists, skipping download.
# voxforge_data/Ara-20091021-wpl.tgz already exists, skipping download.
# voxforge_data/Artem-20121123-ebd.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140314-bje.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140314-btr.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140314-crb.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140314-hwr.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140314-ogu.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140314-scx.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140314-ube.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140314-ukd.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140315-tkd.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140317-uly.tgz already exists, skipping download.
# voxforge_data/AslakKnutsen-20140317-yil.tgz already exists, skipping download.
# voxforge_data/B-20091220-vus.tgz already exists, skipping download.
# voxforge_data/B-20091220-zaq.tgz already exists, skipping download.
# voxforge_data/B-20091221-pxt.tgz already exists, skipping download.
# voxforge_data/B-20091230-umt.tgz already exists, skipping download.
# voxforge_data/B-20091230-yjo.tgz already exists, skipping download.
# voxforge_data/BFG-20120316-bdl.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-brs.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-hgw.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-iux.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-jpg.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-mba.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-qpx.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-sjx.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-unp.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-uop.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-wit.tgz already exists, skipping download.
# voxforge_data/Bahoke-20130721-zau.tgz already exists, skipping download.
# voxforge_data/Bareford-20101110-qkl.tgz already exists, skipping download.
# voxforge_data/Bassel-20120209-xky.tgz already exists, skipping download.
# voxforge_data/Berrym-20101102-aiv.tgz already exists, skipping download.
# voxforge_data/BhushanNKIITBombay-20140219-bbj.tgz already exists, skipping download.
# voxforge_data/BigMick-20090919-pvv.tgz already exists, skipping download.
# voxforge_data/BillMorgan-20120306-aef.tgz already exists, skipping download.
# voxforge_data/Bitbrit-20090528-fsw.tgz already exists, skipping download.
# voxforge_data/Bitbrit-20090528-yit.tgz already exists, skipping download.
# voxforge_data/Blackdrive-20080605-vwx.tgz already exists, skipping download.
# voxforge_data/Blenderkitty-20090615-qcv.tgz already exists, skipping download.
# voxforge_data/Blenderkitty-20090615-rjb.tgz already exists, skipping download.
# voxforge_data/Blenderkitty-20090615-svy.tgz already exists, skipping download.
# voxforge_data/Blenderkitty-20090615-tsi.tgz already exists, skipping download.
# voxforge_data/Blenderkitty-20090615-ytz.tgz already exists, skipping download.
# voxforge_data/BlindPilot-20100610-ama.tgz already exists, skipping download.
# voxforge_data/BlindPilot-20100610-bzv.tgz already exists, skipping download.
# voxforge_data/BlindPilot-20100610-hnf.tgz already exists, skipping download.
# voxforge_data/BlindPilot-20100610-kko.tgz already exists, skipping download.
# voxforge_data/BlindPilot-20100610-ulk.tgz already exists, skipping download.
# voxforge_data/BlueAgent-20120819-dok.tgz already exists, skipping download.
# voxforge_data/BlueAgent-20120819-fjr.tgz already exists, skipping download.
# voxforge_data/BlueB-20090727-ckj.tgz already exists, skipping download.
# voxforge_data/BlueB-20090727-poc.tgz already exists, skipping download.
# voxforge_data/Bob-20100106-mwu.tgz already exists, skipping download.
# voxforge_data/BobHallstrom-20150105-tmy.tgz already exists, skipping download.
# voxforge_data/BobHallstrom-20150105-uii.tgz already exists, skipping download.
# voxforge_data/BobHallstrom-20150105-zdp.tgz already exists, skipping download.
# voxforge_data/BossOfTheGame-20090129-hzr.tgz already exists, skipping download.
# voxforge_data/Bossalicious-20151224-tul.tgz already exists, skipping download.
# voxforge_data/Bradders-20080630-bli.tgz already exists, skipping download.
# voxforge_data/Bradders-20080630-cqm.tgz already exists, skipping download.
# voxforge_data/Bradders-20080630-kja.tgz already exists, skipping download.
# voxforge_data/Bradders-20080701-yvh.tgz already exists, skipping download.
# voxforge_data/BradenJH-20110519-hvn.tgz already exists, skipping download.
# voxforge_data/Brittishenglishscottish20yomale-20091005-nty.tgz already exists, skipping download.
# voxforge_data/Brozkeff-20111229-drc.tgz already exists, skipping download.
# voxforge_data/BruceCouper-20080305-owt.tgz already exists, skipping download.
# voxforge_data/BruceCouper-20080305-qcd.tgz already exists, skipping download.
# voxforge_data/BruceCouper-20080305-yre.tgz already exists, skipping download.
# voxforge_data/BrunoChagas-20140807-wmy.tgz already exists, skipping download.
# voxforge_data/Buddyboy-20110710-uco.tgz already exists, skipping download.
# voxforge_data/CNJ-20120417-jbe.tgz already exists, skipping download.
# voxforge_data/CNJ-20120417-stg.tgz already exists, skipping download.
# voxforge_data/CNJ-20120418-fce.tgz already exists, skipping download.
# voxforge_data/CNJ-20120418-pjw.tgz already exists, skipping download.
# voxforge_data/Caatbells-20111019-dqd.tgz already exists, skipping download.
# voxforge_data/Campbell-20091230-set.tgz already exists, skipping download.
# voxforge_data/Campbell-20091230-zfs.tgz already exists, skipping download.
# voxforge_data/Campbell-20100103-sne.tgz already exists, skipping download.
# voxforge_data/Campbell-20100103-xez.tgz already exists, skipping download.
# voxforge_data/Campbell-20100104-ldz.tgz already exists, skipping download.
# voxforge_data/Campbell-20100414-oor.tgz already exists, skipping download.
# voxforge_data/CaptainSpok-20090509-rbo.tgz already exists, skipping download.
# voxforge_data/CarlFK-20080617-jii.tgz already exists, skipping download.
# voxforge_data/CarlFK-20080617-tus.tgz already exists, skipping download.
# voxforge_data/Catbbells-20110928-mxl.tgz already exists, skipping download.
# voxforge_data/Catbells-20110421-lxg.tgz already exists, skipping download.
# voxforge_data/Catbells-20110527-zjd.tgz already exists, skipping download.
# voxforge_data/Catbells-20110603-lgi.tgz already exists, skipping download.
# voxforge_data/Catbells-20110604-gtl.tgz already exists, skipping download.
# voxforge_data/Catbells-20110728-etu.tgz already exists, skipping download.
# voxforge_data/Catbells-20110730-xsk.tgz already exists, skipping download.
# voxforge_data/Catbells-20110802-ipv.tgz already exists, skipping download.
# voxforge_data/Catbells-20110802-vyn.tgz already exists, skipping download.
# voxforge_data/Catbells-20110803-vxj.tgz already exists, skipping download.
# voxforge_data/Catbells-20110825-jlz.tgz already exists, skipping download.
# voxforge_data/Catbells-20111007-pxh.tgz already exists, skipping download.
# voxforge_data/Catbells-20111008-awq.tgz already exists, skipping download.
# voxforge_data/Catbells-20111009-xvs.tgz already exists, skipping download.
# voxforge_data/Catbells-20111012-zuc.tgz already exists, skipping download.
# voxforge_data/Catbells-20111013-wzy.tgz already exists, skipping download.
# voxforge_data/Catbells-20111017-hbp.tgz already exists, skipping download.
# voxforge_data/Catbells-20111019-ilk.tgz already exists, skipping download.
# voxforge_data/Catbells-20111122-urx.tgz already exists, skipping download.
# voxforge_data/CbS-20120222-tqn.tgz already exists, skipping download.
# voxforge_data/CbS2-20120222-vbu.tgz already exists, skipping download.
# voxforge_data/Cesy-20110904-dyo.tgz already exists, skipping download.
# voxforge_data/Cesy-20110904-nsb.tgz already exists, skipping download.
# voxforge_data/CezarBocu-20090218-frk.tgz already exists, skipping download.
# voxforge_data/Chandri-20090902-rpp.tgz already exists, skipping download.
# voxforge_data/Chas-20100107-yfs.tgz already exists, skipping download.
# voxforge_data/CheesyBreed-20080413-rna.tgz already exists, skipping download.
# voxforge_data/CheesyBreed-20080413-srs.tgz already exists, skipping download.
# voxforge_data/CheesyBreed-20080413-vhf.tgz already exists, skipping download.
# voxforge_data/CheesyBreed-20080413-zms.tgz already exists, skipping download.
# voxforge_data/CheesyBreed-20080413-zwe.tgz already exists, skipping download.
# voxforge_data/Chirag-20131005-tdj.tgz already exists, skipping download.
# voxforge_data/Chris-20101214-faf.tgz already exists, skipping download.
# voxforge_data/Chrisdan-20081210-yzd.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091029-hfv.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091103-clz.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091103-fwl.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091103-zvt.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091104-fqx.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091104-uhr.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091121-grq.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091121-ouu.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091211-lfs.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091211-zcy.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091213-blg.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091213-dnz.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091213-gzk.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091213-tqw.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091213-wdh.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091214-ddc.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091214-jbh.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091214-nsa.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20091214-wze.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100116-crs.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100116-uja.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100118-fao.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100118-scg.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100118-snw.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100118-vib.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100119-amx.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100119-btm.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100119-ogj.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100119-vlt.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100125-dda.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100125-jot.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100125-nfg.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100125-sil.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100126-eet.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100126-vmq.tgz already exists, skipping download.
# voxforge_data/B-20091230-bvx.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100128-gzl.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100128-pgk.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100128-rug.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100128-smf.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100128-vdz.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-bhk.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-bpi.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-fnm.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-kly.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-kxj.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-mku.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-oaz.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-ocx.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-pxp.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-qxa.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-rlh.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-sjb.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-ugy.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-vvd.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-wdk.tgz already exists, skipping download.
# voxforge_data/Coren-20141121-yfc.tgz already exists, skipping download.
# voxforge_data/CptOatmeal-20080721-vnh.tgz already exists, skipping download.
# voxforge_data/CraigWilliamson-20110616-qvp.tgz already exists, skipping download.
# voxforge_data/CraigWilliamson-20110616-xht.tgz already exists, skipping download.
# voxforge_data/Cristbal-20140516-yeu.tgz already exists, skipping download.
# voxforge_data/DammitCoetzeecom-20101020-qml.tgz already exists, skipping download.
# voxforge_data/DanR-20090223-eta.tgz already exists, skipping download.
# voxforge_data/DanR-20090223-fys.tgz already exists, skipping download.
# voxforge_data/DanR-20090223-qnv.tgz already exists, skipping download.
# voxforge_data/DanR-20090223-uln.tgz already exists, skipping download.
# voxforge_data/DanielHeath-20090117-muu.tgz already exists, skipping download.
# voxforge_data/DanielHeath-20090117-rhz.tgz already exists, skipping download.
# voxforge_data/DanielHeath-20090117-rmo.tgz already exists, skipping download.
# voxforge_data/DanielHeath-20090118-csg.tgz already exists, skipping download.
# voxforge_data/DanielHeath-20090118-ztq.tgz already exists, skipping download.
# voxforge_data/Daniil-20120718-lmm.tgz already exists, skipping download.
# voxforge_data/DanijelK-20100117-pbj.tgz already exists, skipping download.
# voxforge_data/DantheDentalman-20130406-wbj.tgz already exists, skipping download.
# voxforge_data/DantheMan-20100110-pgq.tgz already exists, skipping download.
# voxforge_data/Dantheman-20100110-yvz.tgz already exists, skipping download.
# voxforge_data/Darrr-20170412-ong.tgz already exists, skipping download.
# voxforge_data/Dave-20110728-krm.tgz already exists, skipping download.
# voxforge_data/David-20140127-ifv.tgz already exists, skipping download.
# voxforge_data/David-20140127-wfv.tgz already exists, skipping download.
# voxforge_data/DavidBender-20120617-igv.tgz already exists, skipping download.
# voxforge_data/DavidG-20071112-llp.tgz already exists, skipping download.
# voxforge_data/DavidL-20091116-kth.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-bnh.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-csg.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-duk.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-fwe.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-gcr.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-gjs.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-goj.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-ixh.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-mlw.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-ocj.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-wjl.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-wnf.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-yll.tgz already exists, skipping download.
# voxforge_data/DavidL-20091117-zgj.tgz already exists, skipping download.
# voxforge_data/DavidSowerby-20130308-ycz.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-bne.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-bqy.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-bzi.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-cmf.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-cxg.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-cxm.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-czn.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-dac.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-fmi.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-ghe.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-gre.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-hsi.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-hvo.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-hvv.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-jdw.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-mli.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-mzz.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-ono.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-qvd.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-rmx.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-tmu.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-top.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-vad.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-vmo.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-wuk.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-ygs.tgz already exists, skipping download.
# voxforge_data/Dcoetzee-20110429-plk.tgz already exists, skipping download.
# voxforge_data/DebjitBiswas-20100207-fvv.tgz already exists, skipping download.
# voxforge_data/DebjitBiswas-20100207-xzv.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-cso.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-egq.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-evd.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-hmv.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-ile.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-mdq.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-qjb.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-qnp.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-qsa.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-tco.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-tgn.tgz already exists, skipping download.
# voxforge_data/Decent-20110516-ugs.tgz already exists, skipping download.
# voxforge_data/DeepBlue-20121003-jmk.tgz already exists, skipping download.
# voxforge_data/DeepBlue-20130305-ydd.tgz already exists, skipping download.
# voxforge_data/Derek-20090226-atf.tgz already exists, skipping download.
# voxforge_data/Derek-20090226-kzq.tgz already exists, skipping download.
# voxforge_data/Derek-20090226-wrz.tgz already exists, skipping download.
# voxforge_data/DermotColeman-20111125-uom.tgz already exists, skipping download.
# voxforge_data/Diego-20131023-zpg.tgz already exists, skipping download.
# voxforge_data/Dimon-20120702-smx.tgz already exists, skipping download.
# voxforge_data/DomikCZ-20110610-lfs.tgz already exists, skipping download.
# voxforge_data/Donato-20090521-eji.tgz already exists, skipping download.
# voxforge_data/Doogie-20100526-gdk.tgz already exists, skipping download.
# voxforge_data/DouglasDecicco-20140117-svz.tgz already exists, skipping download.
# voxforge_data/Dra-20150325-xcm.tgz already exists, skipping download.
# voxforge_data/DungFu-20090428-twq.tgz already exists, skipping download.
# voxforge_data/DungFu-20090428-yly.tgz already exists, skipping download.
# voxforge_data/EFLwithErika-20120719-doe.tgz already exists, skipping download.
# voxforge_data/EFLwithErika-20120719-ijb.tgz already exists, skipping download.
# voxforge_data/EFLwithErika-20120719-scv.tgz already exists, skipping download.
# voxforge_data/ESimpray-20150122-bvx.tgz already exists, skipping download.
# voxforge_data/ESimpray-20150122-jdj.tgz already exists, skipping download.
# voxforge_data/ESimpray-20150122-rgu.tgz already exists, skipping download.
# voxforge_data/ESimpray-20150122-xjf.tgz already exists, skipping download.
# voxforge_data/ESimpray-20150123-esc.tgz already exists, skipping download.
# voxforge_data/ESimpray-20150123-qlg.tgz already exists, skipping download.
# voxforge_data/ESimpray-20150124-moi.tgz already exists, skipping download.
# voxforge_data/ESimpray-20150125-ndx.tgz already exists, skipping download.
# voxforge_data/ESimpray-20150125-svl.tgz already exists, skipping download.
# voxforge_data/ETT-20090329-typ.tgz already exists, skipping download.
# voxforge_data/EagleX-20071225-npo.tgz already exists, skipping download.
# voxforge_data/Edman274-20090103-fja.tgz already exists, skipping download.
# voxforge_data/Edman274-20090103-fmy.tgz already exists, skipping download.
# voxforge_data/Edman274-20090103-vga.tgz already exists, skipping download.
# voxforge_data/Edman274-20090511-cxp.tgz already exists, skipping download.
# voxforge_data/Edman274-20091113-qfw.tgz already exists, skipping download.
# voxforge_data/Eibriel-20120211-grr.tgz already exists, skipping download.
# voxforge_data/Elliot-20180512-kdi.tgz already exists, skipping download.
# voxforge_data/Elvis-20120526-chb.tgz already exists, skipping download.
# voxforge_data/Emil-20130420-opl.tgz already exists, skipping download.
# voxforge_data/Eresus-20090416-ked.tgz already exists, skipping download.
# voxforge_data/Eresus-20090416-zdx.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140503-iam.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140503-lev.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140503-pkq.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140506-bbs.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140509-cyk.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140509-eix.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140509-llu.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140509-rfk.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140509-rnj.tgz already exists, skipping download.
# voxforge_data/EricHedekar-20140514-cho.tgz already exists, skipping download.
# voxforge_data/EricV-20120527-jyq.tgz already exists, skipping download.
# voxforge_data/EricV-20120527-sdq.tgz already exists, skipping download.
# voxforge_data/EricV-20120527-stf.tgz already exists, skipping download.
# voxforge_data/Ertain-20100728-eum.tgz already exists, skipping download.
# voxforge_data/Ertain-20100728-euy.tgz already exists, skipping download.
# voxforge_data/Ertain-20100728-jxz.tgz already exists, skipping download.
# voxforge_data/Ertain-20100728-twq.tgz already exists, skipping download.
# voxforge_data/Ertain-20101126-abx.tgz already exists, skipping download.
# voxforge_data/Ertain-20101126-xnl.tgz already exists, skipping download.
# voxforge_data/Ertain-20110602-lec.tgz already exists, skipping download.
# voxforge_data/Ertain-20110602-zpj.tgz already exists, skipping download.
# voxforge_data/Ertain-20110621-jcl.tgz already exists, skipping download.
# voxforge_data/Ertain-20110719-osz.tgz already exists, skipping download.
# voxforge_data/Ertain-20140805-eeb.tgz already exists, skipping download.
# voxforge_data/Ertain-20140805-nqz.tgz already exists, skipping download.
# voxforge_data/Ertain-20140805-rus.tgz already exists, skipping download.
# voxforge_data/Ertain-20140805-tez.tgz already exists, skipping download.
# voxforge_data/Ertain-20140805-yaw.tgz already exists, skipping download.
# voxforge_data/Ertain-20140808-kai.tgz already exists, skipping download.
# voxforge_data/Ertain-20140808-lmk.tgz already exists, skipping download.
# voxforge_data/Ertain-20140808-lyt.tgz already exists, skipping download.
# voxforge_data/Ertain-20140808-qeo.tgz already exists, skipping download.
# voxforge_data/Ertain-20140905-bnc.tgz already exists, skipping download.
# voxforge_data/Ertain-20140905-ptf.tgz already exists, skipping download.
# voxforge_data/Ertain-20140905-qsa.tgz already exists, skipping download.
# voxforge_data/Ertain-20170122-hdh.tgz already exists, skipping download.
# voxforge_data/Ertain-20170122-qhq.tgz already exists, skipping download.
# voxforge_data/Ertain-20170122-qmz.tgz already exists, skipping download.
# voxforge_data/Ertain-20170123-fik.tgz already exists, skipping download.
# voxforge_data/Ertain-20170123-ojc.tgz already exists, skipping download.
# voxforge_data/Evan-20100320-plg.tgz already exists, skipping download.
# voxforge_data/Everett-20130514-hkp.tgz already exists, skipping download.
# voxforge_data/FEDboy-20131221-pmq.tgz already exists, skipping download.
# voxforge_data/ColinBeckingham-20100126-xwq.tgz already exists, skipping download.
# voxforge_data/FatFrankie-20110321-ktt.tgz already exists, skipping download.
# voxforge_data/Felipe-20120510-rlo.tgz already exists, skipping download.
# voxforge_data/Finch-20140816-ell.tgz already exists, skipping download.
# voxforge_data/Firefox005-20100820-jgs.tgz already exists, skipping download.
# voxforge_data/Firefox005-20100820-lbo.tgz already exists, skipping download.
# voxforge_data/Firefox005-20100820-qku.tgz already exists, skipping download.
# voxforge_data/Firefox005-20100820-wyt.tgz already exists, skipping download.
# voxforge_data/Firefox005-20100820-xye.tgz already exists, skipping download.
# voxforge_data/Flagship172007-20130623-crz.tgz already exists, skipping download.
# voxforge_data/Flagship172007-20130623-lll.tgz already exists, skipping download.
# voxforge_data/Flagship172007-20130623-pnh.tgz already exists, skipping download.
# voxforge_data/Flllapy-20140115-ttp.tgz already exists, skipping download.
# voxforge_data/Flowerbot-20111128-eio.tgz already exists, skipping download.
# voxforge_data/Flowerbot-20111128-lha.tgz already exists, skipping download.
# voxforge_data/Flowerbot-20111128-oot.tgz already exists, skipping download.
# voxforge_data/Francisco-20120123-fqo.tgz already exists, skipping download.
# voxforge_data/Francisco-20120123-vsa.tgz already exists, skipping download.
# voxforge_data/FrankdeLange-20080718-xkd.tgz already exists, skipping download.
# voxforge_data/FrankdeLange-20080718-zto.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-bnh.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-cnj.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-dcw.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-gqa.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-juh.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-kvl.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-mij.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-mkg.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-qpg.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-qzs.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-xbz.tgz already exists, skipping download.
# voxforge_data/FrozenFire-20080827-yeq.tgz already exists, skipping download.
# voxforge_data/G-20080425-itf.tgz already exists, skipping download.
# voxforge_data/GMP-20170301-qzc.tgz already exists, skipping download.
# voxforge_data/GS-20130527-fxh.tgz already exists, skipping download.
# voxforge_data/GamaBedolla-20150210-jbr.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-awo.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-bbg.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-dyd.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-jhc.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-jvx.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-kew.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-ksv.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-lqm.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-msr.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-oxm.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-pdo.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-trp.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-uva.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-why.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-zey.tgz already exists, skipping download.
# voxforge_data/GaylandGGump-20141207-zlh.tgz already exists, skipping download.
# voxforge_data/Georgio-20100123-efd.tgz already exists, skipping download.
# voxforge_data/Gerard-20140525-res.tgz already exists, skipping download.
# voxforge_data/Gerry-20111231-kfv.tgz already exists, skipping download.
# voxforge_data/Gerwin-20090423-ite.tgz already exists, skipping download.
# voxforge_data/Gowrav-20120430-bmv.tgz already exists, skipping download.
# voxforge_data/Graham-20100520-guc.tgz already exists, skipping download.
# voxforge_data/Graham-20100520-wwj.tgz already exists, skipping download.
# voxforge_data/GrahamPhillips-20071111-oxp.tgz already exists, skipping download.
# voxforge_data/Grill-20120728-sel.tgz already exists, skipping download.
# voxforge_data/Gulain-20140302-jof.tgz already exists, skipping download.
# voxforge_data/GusSCalabrese-20100331-eik.tgz already exists, skipping download.
# voxforge_data/GusSCalabrese-20100331-jxn.tgz already exists, skipping download.
# voxforge_data/Gweilo-20081014-jlz.tgz already exists, skipping download.
# voxforge_data/H2CO3-20120122-dli.tgz already exists, skipping download.
# voxforge_data/H2CO3-20120122-sla.tgz already exists, skipping download.
# voxforge_data/Hadlington-20130720-pwc.tgz already exists, skipping download.
# voxforge_data/Haider-20150429-lzn.tgz already exists, skipping download.
# voxforge_data/HansTheil-20111211-lth.tgz already exists, skipping download.
# voxforge_data/Heber-20130715-mwp.tgz already exists, skipping download.
# voxforge_data/Henry-20130715-swy.tgz already exists, skipping download.
# voxforge_data/HessesiaN-20080605-ahm.tgz already exists, skipping download.
# voxforge_data/Huey-20110823-wdi.tgz already exists, skipping download.
# voxforge_data/Hw-20100511-yul.tgz already exists, skipping download.
# voxforge_data/Hyshinara-20080326-cfp.tgz already exists, skipping download.
# voxforge_data/Hyshinara-20080326-uul.tgz already exists, skipping download.
# voxforge_data/Hyshinara-20080326-vfv.tgz already exists, skipping download.
# voxforge_data/Hyshinara-20080326-zbx.tgz already exists, skipping download.
# voxforge_data/Ilya-20130120-jnp.tgz already exists, skipping download.
# voxforge_data/J0hnny_b14z3-20111219-ibu.tgz already exists, skipping download.
# voxforge_data/J0hnny_b14z3-20111219-rjo.tgz already exists, skipping download.
# voxforge_data/JAdamCraig-20110209-qik.tgz already exists, skipping download.
# voxforge_data/JCWILL-20131104-xtn.tgz already exists, skipping download.
# voxforge_data/JD-20100612-ass.tgz already exists, skipping download.
# voxforge_data/JD-20100612-kko.tgz already exists, skipping download.
# voxforge_data/JGatlin-20100328-dzt.tgz already exists, skipping download.
# voxforge_data/JRB-20080602-keb.tgz already exists, skipping download.
# voxforge_data/JRB-20080602-qyg.tgz already exists, skipping download.
# voxforge_data/JVUnderground-20100821-qxi.tgz already exists, skipping download.
# voxforge_data/J_N-20120509-ztp.tgz already exists, skipping download.
# voxforge_data/JamesHays-20090703-gok.tgz already exists, skipping download.
# voxforge_data/JanusDaniels-20100720-pkl.tgz already exists, skipping download.
# voxforge_data/Jared-20160529-cyy.tgz already exists, skipping download.
# voxforge_data/Jared-20160529-dzj.tgz already exists, skipping download.
# voxforge_data/Jason98-20140105-eku.tgz already exists, skipping download.
# voxforge_data/Jay-20100622-mbg.tgz already exists, skipping download.
# voxforge_data/Jay1853-20140409-dxy.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-btn.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-bvy.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-dmf.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-htt.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-ick.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-jaf.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-mbz.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-nlx.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-ovg.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-psp.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-pus.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-rih.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-ryd.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-siv.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-szm.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-uau.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-vdn.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-vev.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-vre.tgz already exists, skipping download.
# voxforge_data/JayCutlersBrother-20080919-wqq.tgz already exists, skipping download.
# voxforge_data/Jaymin-20140410-zxu.tgz already exists, skipping download.
# voxforge_data/JazziiBuu-20130129-opn.tgz already exists, skipping download.
# voxforge_data/Jeff-20100224-igb.tgz already exists, skipping download.
# voxforge_data/Jelbert-20101129-yao.tgz already exists, skipping download.
# voxforge_data/Jennichan-20130921-vhe.tgz already exists, skipping download.
# voxforge_data/Jeremy-20100627-fbz.tgz already exists, skipping download.
# voxforge_data/Jeremy-20120107-qtq.tgz already exists, skipping download.
# voxforge_data/JimWhite-20100807-dua.tgz already exists, skipping download.
# voxforge_data/JimWhite-20100807-gsx.tgz already exists, skipping download.
# voxforge_data/JimWhite-20100807-lhk.tgz already exists, skipping download.
# voxforge_data/JimWhite-20100807-zqj.tgz already exists, skipping download.
# voxforge_data/JivanAmara-20080724-jeh.tgz already exists, skipping download.
# voxforge_data/JivanAmara-20080724-lvv.tgz already exists, skipping download.
# voxforge_data/JoanPere-20140126-uva.tgz already exists, skipping download.
# voxforge_data/Joel-20080716-qoz.tgz already exists, skipping download.
# voxforge_data/JoelMitchell-20160810-vqt.tgz already exists, skipping download.
# voxforge_data/Joey-20100411-ewf.tgz already exists, skipping download.
# voxforge_data/Joey-20100411-ulh.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080302-hwq.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080302-vvd.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080304-fld.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080304-fse.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080304-lpt.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080304-myv.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080304-wfq.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080306-dbl.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080306-nov.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080306-utt.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080306-xvq.tgz already exists, skipping download.
# voxforge_data/JohanLingen-20080306-zqm.tgz already exists, skipping download.
# voxforge_data/John-20090617-loy.tgz already exists, skipping download.
# voxforge_data/John-20090617-ntl.tgz already exists, skipping download.
# voxforge_data/John-20090617-uqc.tgz already exists, skipping download.
# voxforge_data/JohnGalt-20111007-xxy.tgz already exists, skipping download.
# voxforge_data/JonnyGutteridge-20081120-hav.tgz already exists, skipping download.
# voxforge_data/Joseph-20120404-kit.tgz already exists, skipping download.
# voxforge_data/Joshua-20110325-yze.tgz already exists, skipping download.
# voxforge_data/Kai-20111021-apo.tgz already exists, skipping download.
# voxforge_data/Kai-20111021-uex.tgz already exists, skipping download.
# voxforge_data/KalikiCEO-20130402-cfx.tgz already exists, skipping download.
# voxforge_data/KaloyanKolev-20080907-sdw.tgz already exists, skipping download.
# voxforge_data/KaloyanKolev-20080907-wpo.tgz already exists, skipping download.
# voxforge_data/KaloyanKolev-20080907-xuc.tgz already exists, skipping download.
# voxforge_data/Karageorgos-20090722-lst.tgz already exists, skipping download.
# voxforge_data/Katzer-20140410-lyk.tgz already exists, skipping download.
# voxforge_data/Ken-20110104-gry.tgz already exists, skipping download.
# voxforge_data/KenBloom-20071112-ryd.tgz already exists, skipping download.
# voxforge_data/KenBloom-20071122-ceg.tgz already exists, skipping download.
# voxforge_data/KenBloom-20071122-fot.tgz already exists, skipping download.
# voxforge_data/KenBloom-20071122-tid.tgz already exists, skipping download.
# voxforge_data/KenBloom-20071122-xfp.tgz already exists, skipping download.
# voxforge_data/KenMacRaild-20080702-xic.tgz already exists, skipping download.
# voxforge_data/Keren-20080605-cps.tgz already exists, skipping download.
# voxforge_data/Keren-20080605-uzd.tgz already exists, skipping download.
# voxforge_data/Keren-20080605-vdf.tgz already exists, skipping download.
# voxforge_data/Kero-20120717-yug.tgz already exists, skipping download.
# voxforge_data/KnitGirl-20071113-dil.tgz already exists, skipping download.
# voxforge_data/Kodiak-20100820-sll.tgz already exists, skipping download.
# voxforge_data/Krekos-20150617-ewz.tgz already exists, skipping download.
# voxforge_data/Krekos-20150617-hoc.tgz already exists, skipping download.
# voxforge_data/Krekos-20150617-uml.tgz already exists, skipping download.
# voxforge_data/Krellis-20090608-fyo.tgz already exists, skipping download.
# voxforge_data/Krellis-20090608-jue.tgz already exists, skipping download.
# voxforge_data/Krellis-20090608-kpj.tgz already exists, skipping download.
# voxforge_data/Krellis-20090608-sjw.tgz already exists, skipping download.
# voxforge_data/Krellis-20090608-wuu.tgz already exists, skipping download.
# voxforge_data/Krellis-20090609-ave.tgz already exists, skipping download.
# voxforge_data/Krellis-20090609-nha.tgz already exists, skipping download.
# voxforge_data/Krellis-20090609-wfz.tgz already exists, skipping download.
# voxforge_data/Krishna-20090503-mny.tgz already exists, skipping download.
# voxforge_data/Krishnendhu-20111010-mri.tgz already exists, skipping download.
# voxforge_data/Kristina-20100117-tgp.tgz already exists, skipping download.
# voxforge_data/KrzysztofWierzbicki-20120212-jtv.tgz already exists, skipping download.
# voxforge_data/Kupiakos-20121022-wjd.tgz already exists, skipping download.
# voxforge_data/Kyngo-20170526-zhn.tgz already exists, skipping download.
# voxforge_data/Kyton-20081201-bay.tgz already exists, skipping download.
# voxforge_data/Kyton-20081201-gzs.tgz already exists, skipping download.
# voxforge_data/Kyton-20081201-isv.tgz already exists, skipping download.
# voxforge_data/Kyton-20081201-jmv.tgz already exists, skipping download.
# voxforge_data/Kyton-20081201-sge.tgz already exists, skipping download.
# voxforge_data/Kyton-20081201-srl.tgz already exists, skipping download.
# voxforge_data/Kyton-20081201-tvr.tgz already exists, skipping download.
# voxforge_data/Kyton-20081201-uan.tgz already exists, skipping download.
# voxforge_data/Kyton-20081201-vtl.tgz already exists, skipping download.
# voxforge_data/L1ttl3J1m-20090701-fhz.tgz already exists, skipping download.
# voxforge_data/L1ttl3J1m-20090701-hij.tgz already exists, skipping download.
# voxforge_data/L1ttl3J1m-20090701-yfs.tgz already exists, skipping download.
# voxforge_data/LAVEENAZ-20100515-soe.tgz already exists, skipping download.
# voxforge_data/LAVEENAZ-20100515-zaq.tgz already exists, skipping download.
# voxforge_data/LAVEENAZ-20100516-fjt.tgz already exists, skipping download.
# voxforge_data/LAVEENAZ-20100516-fmt.tgz already exists, skipping download.
# voxforge_data/LAVEENAZ-20100516-gpj.tgz already exists, skipping download.
# voxforge_data/LAVEENAZ-20100516-kgh.tgz already exists, skipping download.
# voxforge_data/LAVEENAZ-20100516-yxi.tgz already exists, skipping download.
# voxforge_data/LMA-20091008-uhh.tgz already exists, skipping download.
# voxforge_data/LRMAAX-20120508-nnj.tgz already exists, skipping download.
# voxforge_data/Lafsq-20130703-dcl.tgz already exists, skipping download.
# voxforge_data/Leonardo-20120723-szo.tgz already exists, skipping download.
# voxforge_data/Lexen-20071106-mrd.tgz already exists, skipping download.
# voxforge_data/Logomancer-20100820-hhi.tgz already exists, skipping download.
# voxforge_data/Logomancer-20100820-inh.tgz already exists, skipping download.
# voxforge_data/Logomancer-20100820-qcu.tgz already exists, skipping download.
# voxforge_data/Lomoco-20081006-xbi.tgz already exists, skipping download.
# voxforge_data/Luca-20091217-zis.tgz already exists, skipping download.
# voxforge_data/Lucas-20130610-gju.tgz already exists, skipping download.
# voxforge_data/Luis-20130226-peg.tgz already exists, skipping download.
# voxforge_data/LuisManuelPradoMoreno-20130104-hqb.tgz already exists, skipping download.
# voxforge_data/Fandark-20100822-acy.tgz already exists, skipping download.
# voxforge_data/LukasFT-20121020-wqd.tgz already exists, skipping download.
# voxforge_data/LukeSkywalker-20090509-sni.tgz already exists, skipping download.
# voxforge_data/LunaTick-20080319-ill.tgz already exists, skipping download.
# voxforge_data/LunaTick-20080319-owg.tgz already exists, skipping download.
# voxforge_data/LunaTick-20080319-oyi.tgz already exists, skipping download.
# voxforge_data/LunaTick-20080321-ass.tgz already exists, skipping download.
# ...
# Extracted voxforge_data/tomhannen-20080411-cnt.tgz
# Extracted voxforge_data/tomhannen-20080411-djj.tgz
# Extracted voxforge_data/tomhannen-20080411-dwh.tgz
# Extracted voxforge_data/tomhannen-20080411-ebw.tgz
# Extracted voxforge_data/tomhannen-20080411-ely.tgz
# Extracted voxforge_data/tomhannen-20080411-epi.tgz
# Extracted voxforge_data/tomhannen-20080411-flh.tgz
# Extracted voxforge_data/tomhannen-20080411-ium.tgz
# Extracted voxforge_data/tomhannen-20080411-mcn.tgz
# Extracted voxforge_data/tomhannen-20080411-lvm.tgz
# Extracted voxforge_data/tomhannen-20080411-kvt.tgz
# Extracted voxforge_data/tomhannen-20080411-mth.tgz
# Extracted voxforge_data/tomhannen-20080411-mjo.tgz
# Extracted voxforge_data/tomhannen-20080411-qbo.tgz
# Extracted voxforge_data/tomhannen-20080411-pgd.tgz
# Extracted voxforge_data/tomhannen-20080411-qdo.tgz
# Extracted voxforge_data/tomhannen-20080411-pvb.tgz
# Extracted voxforge_data/tomhannen-20080411-qlp.tgz
# Extracted voxforge_data/tomhannen-20080411-qvl.tgz
# Extracted voxforge_data/tomhannen-20080411-qxk.tgz
# Extracted voxforge_data/tomhannen-20080411-rmh.tgz
# Extracted voxforge_data/tomhannen-20080411-rfx.tgz
# Extracted voxforge_data/tomhannen-20080411-sbn.tgz
# Extracted voxforge_data/tomhannen-20080411-vds.tgz
# Extracted voxforge_data/tomhannen-20080411-xpi.tgz
# Extracted voxforge_data/tomhannen-20080411-xzk.tgz
# Extracted voxforge_data/tomhannen-20080411-ybm.tgz
# Extracted voxforge_data/tomhannen-20080411-yvm.tgz
# Extracted voxforge_data/tomhannen-20080411-zcb.tgz
# Extracted voxforge_data/tomhannen-20080411-yvy.tgz
# Extracted voxforge_data/tomhannen-20080411-zib.tgz
# Extracted voxforge_data/topherfangio-20080604-dgk.tgz
# Extracted voxforge_data/topherfangio-20080604-edr.tgz
# Extracted voxforge_data/tomhannwn-20080411-zsu.tgz
# Extracted voxforge_data/topherfangio-20080604-egr.tgz
# Extracted voxforge_data/tomhannwn-20080411-acr.tgz
# Extracted voxforge_data/topherfangio-20080604-ejv.tgz
# Extracted voxforge_data/topherfangio-20080604-fcf.tgz
# Extracted voxforge_data/topherfangio-20080604-feu.tgz
# Extracted voxforge_data/topherfangio-20080604-imo.tgz
# Extracted voxforge_data/topherfangio-20080604-hkl.tgz
# Extracted voxforge_data/topherfangio-20080604-fvf.tgz
# Extracted voxforge_data/topherfangio-20080604-jvb.tgz
# Extracted voxforge_data/topherfangio-20080604-ira.tgz
# Extracted voxforge_data/topherfangio-20080604-kzc.tgz
# Extracted voxforge_data/topherfangio-20080604-nhn.tgz
# Extracted voxforge_data/topherfangio-20080604-nan.tgz
# Extracted voxforge_data/topherfangio-20080604-nnk.tgz
# Extracted voxforge_data/topherfangio-20080604-nvd.tgz
# Extracted voxforge_data/topherfangio-20080604-ojg.tgz
# Extracted voxforge_data/topherfangio-20080604-sci.tgz
# Extracted voxforge_data/topherfangio-20080604-qut.tgz
# Extracted voxforge_data/topherfangio-20080604-spf.tgz
# Extracted voxforge_data/topherfangio-20080604-rrw.tgz
# Extracted voxforge_data/topherfangio-20080604-sxs.tgz
# Extracted voxforge_data/topherfangio-20080604-wvs.tgz
# Extracted voxforge_data/tomhannen-20080409.tgz
# Extracted voxforge_data/topherfangio-20080604-trp.tgz
# Extracted voxforge_data/topherfangio-20080604-tjf.tgz
# Extracted voxforge_data/topherfangio-20080604-twl.tgz
# Extracted voxforge_data/topherfangio-20080604-tgh.tgz
# Extracted voxforge_data/topherfangio-20080604-wyz.tgz
# Extracted voxforge_data/topherfangio-20080604-xmp.tgz
# Extracted voxforge_data/tozden-20090830-lfh.tgz
# Extracted voxforge_data/treaki-20140114-bhv.tgz
# Extracted voxforge_data/tozden-20090830-irc.tgz
# Extracted voxforge_data/toranome-20140806-cbu.tgz
# Extracted voxforge_data/toshihide-20100502-drx.tgz
# Extracted voxforge_data/tristau-20090801-jli.tgz
# Extracted voxforge_data/trimbak-20100315-yia.tgz
# Extracted voxforge_data/trimbak-20100315-icl.tgz
# Extracted voxforge_data/tristau-20090801-txl.tgz
# Extracted voxforge_data/trinity15-20120923-gyk.tgz
# Extracted voxforge_data/tristau-20090801-vnx.tgz
# Extracted voxforge_data/tristau-20090801-wrv.tgz
# Extracted voxforge_data/tristau-20090801-whn.tgz
# Extracted voxforge_data/tristau-20090801-xxp.tgz
# Extracted voxforge_data/troya-20080602-icd.tgz
# Extracted voxforge_data/ts87-20090126-iop.tgz
# Extracted voxforge_data/ts87-20090126-etq.tgz
# Extracted voxforge_data/trrichar-20130915-xng.tgz
# Extracted voxforge_data/ts87-20090126-gzh.tgz
# Extracted voxforge_data/ts87-20090126-omo.tgz
# Extracted voxforge_data/trevarthan-070403-vf3.tgz
# Extracted voxforge_data/tsmock-20110613-thv.tgz
# Extracted voxforge_data/tsmock-20110613-zmu.tgz
# Extracted voxforge_data/ts87-20090126-wns.tgz
# Extracted voxforge_data/tsmock-20111112-aee.tgz
# Extracted voxforge_data/tsmock-20111112-ava.tgz
# Extracted voxforge_data/trevarthan-070403.tgz
# Extracted voxforge_data/tsmock-20120308-ltq.tgz
# Extracted voxforge_data/tsmock-20120308-zuk.tgz
# Extracted voxforge_data/tsmock-20120308-xrl.tgz
# Extracted voxforge_data/tsmock-20120701-qts.tgz
# Extracted voxforge_data/tsmock-20120704-aie.tgz
# Extracted voxforge_data/tsmock-20120703-pgs.tgz
# Extracted voxforge_data/tsmock-20120705-zdm.tgz
# Extracted voxforge_data/tsmock-20120703-ytp.tgz
# Extracted voxforge_data/tsmock-20120707-dki.tgz
# Extracted voxforge_data/tsmock-20120707-mbv.tgz
# Extracted voxforge_data/tsmock-20120707-moo.tgz
# Extracted voxforge_data/tsmock-20120707-sdu.tgz
# Extracted voxforge_data/tsmock-20120707-pbk.tgz
# Extracted voxforge_data/tsmock-20120716-ysn.tgz
# Extracted voxforge_data/tsmock-20120707-shn.tgz
# Extracted voxforge_data/tsmock-20120716-ulk.tgz
# Extracted voxforge_data/tsmock-20120719-ccb.tgz
# Extracted voxforge_data/tsmock-20120719-ids.tgz
# Extracted voxforge_data/tsmock-20120719-get.tgz
# Extracted voxforge_data/tsmock-20120719-gpy.tgz
# Extracted voxforge_data/tsmock-20120719-rlx.tgz
# Extracted voxforge_data/tsmock-20120719-ljp.tgz
# Extracted voxforge_data/tsmock-20120719-nfc.tgz
# Extracted voxforge_data/tsmock-20120719-xfc.tgz
# Extracted voxforge_data/tis-20080416-tou.tgz
# Extracted voxforge_data/tsmock-20120720-wul.tgz
# Extracted voxforge_data/tsmock-20120719-yev.tgz
# Extracted voxforge_data/tsmock-20120722-gsn.tgz
# Extracted voxforge_data/tsmock-20120722-hjf.tgz
# Extracted voxforge_data/tsmock-20120722-hnt.tgz
# Extracted voxforge_data/tsmock-20120722-yvt.tgz
# Extracted voxforge_data/tsmock-20120722-vca.tgz
# Extracted voxforge_data/tsmock-20120724-apd.tgz
# Extracted voxforge_data/tsmock-20120724-mcz.tgz
# Extracted voxforge_data/tsmock-20120728-oel.tgz
# Extracted voxforge_data/tsmock-20120728-ryi.tgz
# Extracted voxforge_data/tsmock-20120806-aro.tgz
# Extracted voxforge_data/tsmock-20120806-gfu.tgz
# Extracted voxforge_data/tsmock-20120806-bue.tgz
# Extracted voxforge_data/tsmock-20120806-hlo.tgz
# Extracted voxforge_data/tsmock-20120806-hmu.tgz
# Extracted voxforge_data/tsmock-20120806-uoa.tgz
# Extracted voxforge_data/tsmock-20120806-hrw.tgz
# Extracted voxforge_data/tsmock-20120813-uvo.tgz
# Extracted voxforge_data/tsmock-20120806-vpt.tgz
# Extracted voxforge_data/tsmock-20120930-uyi.tgz
# Extracted voxforge_data/tsmock-20120930-jyf.tgz
# Extracted voxforge_data/tsmock-20120815-jlr.tgz
# Extracted voxforge_data/tsmock-20121014-uyq.tgz
# Extracted voxforge_data/tsmock-20121207-dwx.tgz
# Extracted voxforge_data/tsmock-20121213-jgc.tgz
# Extracted voxforge_data/tsmock-20121207-akg.tgz
# Extracted voxforge_data/tsmock-20121213-qwt.tgz
# Extracted voxforge_data/tsmock-20121207-osi.tgz
# Extracted voxforge_data/tsmock-20121213-swe.tgz
# Extracted voxforge_data/tsmock-20121213-utq.tgz
# Extracted voxforge_data/tsmock-20121215-gtn.tgz
# Extracted voxforge_data/tsmock-20130622-aho.tgz
# Extracted voxforge_data/tsmock-20130622-etj.tgz
# Extracted voxforge_data/tsmock-20130720-pgq.tgz
# Extracted voxforge_data/tsmock-20130610-orj.tgz
# Extracted voxforge_data/tsmock-20140713-jau.tgz
# Extracted voxforge_data/ttm-20071009-poe.tgz
# Extracted voxforge_data/ttm-20071016-poe.tgz
# Extracted voxforge_data/turtleman-20130413-zhx.tgz
# Extracted voxforge_data/ttm-20071102-poe.tgz
# Extracted voxforge_data/ttm-20071007.tgz
# Extracted voxforge_data/ttm-20071024-poe.tgz
# Extracted voxforge_data/turtleman-20130621-xjz.tgz
# Extracted voxforge_data/ttm-20071016.tgz
# Extracted voxforge_data/twoshades-20090322-oyf.tgz
# Extracted voxforge_data/ttm-20071102.tgz
# Extracted voxforge_data/uklebot-20090813-jub.tgz
# Extracted voxforge_data/uklebot-20090813-yez.tgz
# Extracted voxforge_data/twoshades-20090322-rqr.tgz
# Extracted voxforge_data/uklebot-20090813-zxl.tgz
# Extracted voxforge_data/ttm-20071024.tgz
# Extracted voxforge_data/ulor-20100711-uov.tgz
# Extracted voxforge_data/ulises-20130116-gzk.tgz
# Extracted voxforge_data/unbridledrage-20090106-bvx.tgz
# Extracted voxforge_data/unbridledrage-20090106-clj.tgz
# Extracted voxforge_data/unbridledrage-20090106-dho.tgz
# Extracted voxforge_data/ulrichard-20100205-uxe.tgz
# Extracted voxforge_data/unbridledrage-20090106-drs.tgz
# Extracted voxforge_data/unbridledrage-20090106-dwk.tgz
# Extracted voxforge_data/unbridledrage-20090106-fzs.tgz
# Extracted voxforge_data/unbridledrage-20090106-ifx.tgz
# Extracted voxforge_data/unbridledrage-20090106-gej.tgz
# Extracted voxforge_data/unbridledrage-20090106-han.tgz
# Extracted voxforge_data/unbridledrage-20090106-hpf.tgz
# Extracted voxforge_data/unbridledrage-20090106-kcf.tgz
# Extracted voxforge_data/unbridledrage-20090106-koj.tgz
# Extracted voxforge_data/unbridledrage-20090106-lpl.tgz
# Extracted voxforge_data/unbridledrage-20090106-mqp.tgz
# Extracted voxforge_data/unbridledrage-20090106-ton.tgz
# Extracted voxforge_data/unbridledrage-20090106-uco.tgz
# Extracted voxforge_data/unbridledrage-20090106-toy.tgz
# Extracted voxforge_data/unbridledrage-20090106-meb.tgz
# Extracted voxforge_data/unbridledrage-20090106-xfo.tgz
# Extracted voxforge_data/unbridledrage-20090106-zzt.tgz
# Extracted voxforge_data/unknow-20090722-qcs.tgz
# Extracted voxforge_data/vandev1-20140401-dkn.tgz
# Extracted voxforge_data/vandev1-20140401-lon.tgz
# Extracted voxforge_data/vandev1-20140401-ytt.tgz
# Extracted voxforge_data/vandev1-20140401-ffc.tgz
# Extracted voxforge_data/usaaib-20161111-kkc.tgz
# Extracted voxforge_data/usaaib-20161111-bwv.tgz
# Extracted voxforge_data/vertago1-20090805-dka.tgz
# Extracted voxforge_data/usaaib-20161111-hxe.tgz
# Extracted voxforge_data/vertago1-20090805-ead.tgz
# Extracted voxforge_data/vertago1-20090805-efa.tgz
# Extracted voxforge_data/vertago1-20090805-hyu.tgz
# Extracted voxforge_data/vanja73-20130505-ixz.tgz
# Extracted voxforge_data/vertago1-20090805-mda.tgz
# Extracted voxforge_data/vertago1-20090805-mfz.tgz
# Extracted voxforge_data/vertago1-20090805-qrc.tgz
# Extracted voxforge_data/vikramjb-20080416-cls.tgz
# Extracted voxforge_data/vertago1-20090805-qla.tgz
# Extracted voxforge_data/vikasrij-20130111-bhz.tgz
# Extracted voxforge_data/vince-20071118-tez.tgz
# Extracted voxforge_data/vinay-20120131-luu.tgz
# Extracted voxforge_data/violet6008-20121119-fya.tgz
# Extracted voxforge_data/vinay-20120131-rum.tgz
# Extracted voxforge_data/violet6008-20121119-myk.tgz
# Extracted voxforge_data/violet6008-20121119-xwz.tgz
# Extracted voxforge_data/violet6008-20121119-tsf.tgz
# Extracted voxforge_data/volkerbradley-20121230-nsg.tgz
# Extracted voxforge_data/vklimkov-20121120-mbl.tgz
# Extracted voxforge_data/volkerbradley-20121230-prd.tgz
# Extracted voxforge_data/volkerbradley-20121230-xlt.tgz
# Extracted voxforge_data/volkerbradley-20121230-snc.tgz
# Extracted voxforge_data/volkerbradley-20121230-pwh.tgz
# Extracted voxforge_data/volkerbradley-20121230-zrd.tgz
# Extracted voxforge_data/volkerbradley-20121231-nrj.tgz
# Extracted voxforge_data/voltagex-20100821-opc.tgz
# Extracted voxforge_data/volkerbradley-20130102-myz.tgz
# Extracted voxforge_data/volkerbradley-20121231-zli.tgz
# Extracted voxforge_data/vorcollion-20091013-stb.tgz
# Extracted voxforge_data/vschum-20090719-hak.tgz
# Extracted voxforge_data/volkerbradley-20130102-sal.tgz
# Extracted voxforge_data/vschum-20090719-dob.tgz
# Extracted voxforge_data/vschum-20090719-hfr.tgz
# Extracted voxforge_data/vschum-20090719-ktq.tgz
# Extracted voxforge_data/vschum-20110103-aqz.tgz
# Extracted voxforge_data/wajkordanii-20081116-ggv.tgz
# Extracted voxforge_data/vschum-20090719-rjj.tgz
# Extracted voxforge_data/vschum-20120224-wpn.tgz
# Extracted voxforge_data/wajordanii-20081116-uay.tgz
# Extracted voxforge_data/waldyrious-20140912-dod.tgz
# Extracted voxforge_data/waldyrious-20140912-dtk.tgz
# Extracted voxforge_data/waldyrious-20140912-scj.tgz
# Extracted voxforge_data/wazzyl-20111109-chb.tgz
# Extracted voxforge_data/wegoright-20120303-kwy.tgz
# Extracted voxforge_data/wesjackson-20130502-kky.tgz
# Extracted voxforge_data/whappy-20090617-ltq.tgz
# Extracted voxforge_data/wesjackson-20130502-yeo.tgz
# Extracted voxforge_data/wheel_of_fire-20110405-bkh.tgz
# Extracted voxforge_data/wicke-20090313-dcc.tgz
# Extracted voxforge_data/wheel_of_fire-20110405-ddf.tgz
# Extracted voxforge_data/wicke-20090313-dga.tgz
# Extracted voxforge_data/wicke-20090313-vzl.tgz
# Extracted voxforge_data/wicke-20090313-hep.tgz
# Extracted voxforge_data/wicke-20090313-wnm.tgz
# Extracted voxforge_data/wicke-20090313-yxo.tgz
# Extracted voxforge_data/wicke-20090314-bhq.tgz
# Extracted voxforge_data/wicke-20090314-fdu.tgz
# Extracted voxforge_data/wicke-20090314-jqn.tgz
# Extracted voxforge_data/wicke-20090314-jzq.tgz
# Extracted voxforge_data/wicke-20090314-poa.tgz
# Extracted voxforge_data/wicke-20090314-jtl.tgz
# Extracted voxforge_data/wicke-20090314-tdm.tgz
# Extracted voxforge_data/wicke-20090314-xkm.tgz
# Extracted voxforge_data/wicke-20090314-wup.tgz
# Extracted voxforge_data/wicke-20090314-znl.tgz
# Extracted voxforge_data/wicke-20090316-wii.tgz
# Extracted voxforge_data/wolktm-20090114-kly.tgz
# Extracted voxforge_data/wsloand-20111229-fqk.tgz
# Extracted voxforge_data/xaviergonz-20080419-myf.tgz
# Extracted voxforge_data/xaviergonz-20080419-uje.tgz
# Extracted voxforge_data/wsloand-20111229-ogp.tgz
# Extracted voxforge_data/xaviergonz-20080419-vmv.tgz
# Extracted voxforge_data/xenobyte72-20080530-pgo.tgz
# Extracted voxforge_data/wicke-20071121.tgz
# Extracted voxforge_data/xh-20100802-cht.tgz
# Extracted voxforge_data/xentalion-20101209-zcf.tgz
# Extracted voxforge_data/xh-20100802-aed.tgz
# Extracted voxforge_data/xh-20100802-dvc.tgz
# Extracted voxforge_data/xh-20100802-egd.tgz
# Extracted voxforge_data/xh-20100802-jzc.tgz
# Extracted voxforge_data/xh-20100802-lfs.tgz
# Extracted voxforge_data/xh-20100802-mvp.tgz
# Extracted voxforge_data/xh-20100802-ocg.tgz
# Extracted voxforge_data/xh-20100802-pjn.tgz
# Extracted voxforge_data/xh-20100802-qsv.tgz
# Extracted voxforge_data/xh-20100802-rdg.tgz
# Extracted voxforge_data/xh-20100802-qey.tgz
# Extracted voxforge_data/xh-20100802-yvb.tgz
# Extracted voxforge_data/xori-20140402-igo.tgz
# Extracted voxforge_data/xtophe-20080924-ejb.tgz
# Extracted voxforge_data/xtophe-20080924-hsu.tgz
# Extracted voxforge_data/xtophe-20080924-oqk.tgz
# Extracted voxforge_data/xtophe-20080924-pqx.tgz
# Extracted voxforge_data/xtophe-20080924-wcq.tgz
# Extracted voxforge_data/xtophe-20080924-zhr.tgz
# Extracted voxforge_data/xtophe-20080924-xog.tgz
# Extracted voxforge_data/yanlongwang-20090706-egd.tgz
# Extracted voxforge_data/xtophe-20080924-ulu.tgz
# Extracted voxforge_data/yacineyacine-20111103-qba.tgz
# Extracted voxforge_data/yassin-20081216-ujk.tgz
# Extracted voxforge_data/yebbey-20090217-das.tgz
# Extracted voxforge_data/yoyology-20130628-enc.tgz
# Extracted voxforge_data/yoyology-20130628-uce.tgz
# Extracted voxforge_data/z4k-20090224-ndw.tgz
# Extracted voxforge_data/zaka50-20110113-gfa.tgz
# Extracted voxforge_data/zack-20100514-gvi.tgz
# Extracted voxforge_data/zcarrell-20130728-aji.tgz
# Extracted voxforge_data/zaoter-20110329-kzi.tgz
# Extracted voxforge_data/zcarrell-20130728-xor.tgz
# Extracted voxforge_data/zhao-20130326-hxz.tgz
# Extracted voxforge_data/zeltanaco-20100911-cis.tgz
# Extracted voxforge_data/zid-20100821-kto.tgz
# Extracted voxforge_data/zlp-20100110-gyn.tgz
# Extracted voxforge_data/zhihuich-20130615-xey.tgz
# Extracted voxforge_data/zlp-20100110-hpf.tgz
# Extracted voxforge_data/zlp-20100110-jmb.tgz
# Extracted voxforge_data/zlp-20100110-jwa.tgz
# Extracted voxforge_data/zlp-20100110-kgx.tgz
# Extracted voxforge_data/zlp-20100110-lbe.tgz
# Extracted voxforge_data/zlp-20100110-ujo.tgz
# Extracted voxforge_data/zlp-20100110-wwn.tgz
# Extracted voxforge_data/zlp-20100110-vuh.tgz
# Extracted voxforge_data/zeroschism-20160710.tgz
# All files extracted.

# %%
wav_files = get_vocal_range_wavs()
print(f"Found {len(wav_files)} .wav files in the human vocal range.")
# Out:
# Total .wav files found: 87421
# Filtering .wav files: 100%|██████████████████████████████████████████████████████| 87421/87421 [03:51<00:00, 376.98it/s]
# Filtered to 87421 .wav files within human vocal range.
# Dropped files: 0
# Found 87421 .wav files in the human vocal range.

# %% [markdown]
# # Filtering

# %%
import random

sample_wavs = random.sample(wav_files, 383)

# Init lists
out_of_range_ratios = []
in_range_energies = []
out_range_energies = []

for wav_path in tqdm(sample_wavs, desc="Analyzing sampled .wav files"):
    y, sr = librosa.load(wav_path, sr=None)
    freqs = np.fft.rfftfreq(len(y), d=1/sr)
    spectrum = np.abs(np.fft.rfft(y)) ** 2  # Power spectrum

    in_energy = np.sum(spectrum[freqs <= 280])
    out_energy = np.sum(spectrum[freqs > 280])
    total_energy = in_energy + out_energy

    if total_energy == 0:
        ratio = 0.0
    else:
        ratio = out_energy / total_energy

    in_range_energies.append(in_energy)
    out_range_energies.append(out_energy)
    out_of_range_ratios.append(ratio)

series = pd.Series(out_of_range_ratios, name="out_of_range_ratio")
print(series.describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.95]))
# Out:
# Analyzing sampled .wav files: 100%|██████████████████████████████████████████████████| 383/383 [00:02<00:00, 141.62it/s]
# count    383.000000
# mean       0.581168
# std        0.268646
# min        0.001707
# 25%        0.423423
# 50%        0.638410
# 75%        0.788002
# 90%        0.880268
# 95%        0.919165
# max        0.996774
# Name: out_of_range_ratio, dtype: float64

# %%
def compute_ratio(wav_path):
    y, sr = librosa.load(wav_path, sr=None)
    spectrum = np.abs(np.fft.rfft(y))
    freqs = np.fft.rfftfreq(len(y), d=1/sr)

    in_range = (freqs >= 0) & (freqs <= 280)
    energy_in_range = np.sum(spectrum[in_range])
    energy_total = np.sum(spectrum)
    ratio = 1 - (energy_in_range / energy_total) if energy_total > 0 else 1
    return wav_path, ratio


def filter_by_out_of_range_ratio(wav_paths, threshold):
    """Filter .wav files where too much energy is outside the 0–280 Hz human vocal range."""
    print("Calculating out-of-range energy ratios...")

    with ProcessPoolExecutor(max_workers=10) as executor:
        results = list(tqdm(executor.map(compute_ratio, wav_paths), total=len(wav_paths)))

    filtered = [wav for wav, ratio in results if ratio < threshold]
    dropped = [wav for wav, ratio in results if ratio >= threshold]

    print(f"Kept {len(filtered)} WAV files below threshold ({threshold}).")
    print(f"Dropped {len(dropped)} WAV files due to high out-of-range energy.")
    return filtered

# %%
filtered_wavs = filter_by_out_of_range_ratio(wav_files, threshold=0.9)
# Out:
# Calculating out-of-range energy ratios...
# 100%|████████████████████████████████████████████████████████████████████████████| 87421/87421 [03:58<00:00, 367.12it/s]
# Kept 69038 WAV files below threshold (0.9).
# Dropped 18383 WAV files due to high out-of-range energy.

# %% [markdown]
# # Space for trimming if needed

# %% [markdown]
# # Extract Features & Save as Parquet

# %%
def compute_fft_features_cpu(wav_path):
    """Extract FFT spectrum and frequencies using NumPy. Returns (filename, freqs, spectrum)."""
    y, sr = librosa.load(wav_path, sr=None)
    spectrum = np.abs(np.fft.rfft(y))
    freqs = np.fft.rfftfreq(len(y), d=1/sr)
    
    rel_path = os.path.relpath(wav_path, EXTRACT_DIR)
    return rel_path, freqs, spectrum

def compute_statistics(item):
    """Takes (filename, freqs, spectrum) and returns computed audio features."""
    filename, freqs, spectrum = item

    if len(spectrum) == 0:
        return None

    # Normalize spectrum for spectral entropy and flatness
    spectrum_norm = spectrum / np.sum(spectrum) if np.sum(spectrum) > 0 else np.zeros_like(spectrum)

    # Core stats
    mean_freq = np.mean(freqs) / 1000
    std_freq = np.std(freqs) / 1000
    median_freq = np.median(freqs) / 1000
    first_quantile = np.percentile(freqs, 25) / 1000
    third_quantile = np.percentile(freqs, 75) / 1000
    iqr = third_quantile - first_quantile
    skewness = stats.skew(spectrum)
    kurtosis = stats.kurtosis(spectrum)
    mode_freq = freqs[np.argmax(spectrum)] / 1000
    peak_freq = mode_freq

    # Spectral entropy
    sp_entropy = -np.sum(spectrum_norm * np.log2(spectrum_norm + 1e-10))

    # Spectral flatness (geometric mean / arithmetic mean)
    flatness = stats.gmean(spectrum + 1e-10) / (np.mean(spectrum) + 1e-10)

    # Centroid
    centroid = np.sum(freqs * spectrum) / np.sum(spectrum) / 1000 if np.sum(spectrum) > 0 else 0

    # Modulation index: rough approximation as std/sum
    modindx = np.std(spectrum) / (np.mean(spectrum) + 1e-10)

    return [
        filename, mean_freq, std_freq, median_freq,
        first_quantile, third_quantile, iqr,
        skewness, kurtosis, mode_freq, peak_freq,
        sp_entropy, flatness, centroid, modindx
    ]


def parallel_extract_audio_features(wav_files, batch_size=5000):
    """Extract audio features in batches to avoid overwhelming memory."""
    if not wav_files:
        print("No valid .wav files found for feature extraction.")
        return

    total = len(wav_files)
    print(f"Step 1: Computing FFT (CPU) for {total} .wav files in batches of {batch_size}...")

    all_results = []

    for i in range(0, total, batch_size):
        batch_files = wav_files[i:i + batch_size]
        print(f"\nProcessing batch {i // batch_size + 1} / {(total - 1) // batch_size + 1} ({len(batch_files)} files)")

        fft_outputs = []
        for wav in tqdm(batch_files, desc="Computing FFT (CPU)", leave=False):
            try:
                fft_outputs.append(compute_fft_features_cpu(wav))
            except Exception as e:
                print(f"Error processing {wav}: {e}")

        print("Step 2: Computing statistics (parallel CPU)...")
        with ProcessPoolExecutor(max_workers=10) as executor:
            batch_results = list(tqdm(executor.map(compute_statistics, fft_outputs),
                                      total=len(fft_outputs), desc="Computing Stats", leave=False))

        batch_results = [r for r in batch_results if r is not None]
        all_results.extend(batch_results)

    df = pd.DataFrame(all_results, columns=[
    "filename", "mean_freq_kHz", "std_freq_kHz", "median_freq_kHz",
    "first_quantile_kHz", "third_quantile_kHz", "iqr_kHz",
    "skewness", "kurtosis", "mode_freq_kHz", "peak_freq_kHz",
    "sp_entropy", "flatness", "centroid_kHz", "modindx"
    ])

    df.to_parquet(FEATURES_FILE)
    print(f"\n✅ Feature extraction complete. Saved to {FEATURES_FILE}.")

# %%
parallel_extract_audio_features(filtered_wavs)
# Out:
# Step 1: Computing FFT (CPU) for 69038 .wav files in batches of 5000...
#
# Processing batch 1 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 2 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 3 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 4 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 5 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 6 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 7 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 8 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 9 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 10 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 11 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 12 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 13 / 14 (5000 files)
# Step 2: Computing statistics (parallel CPU)...
# Processing batch 14 / 14 (4038 files)
# Step 2: Computing statistics (parallel CPU)...
# ✅ Feature extraction complete. Saved to voxforge_data/audio_features.parquet.

# %%
df = pd.read_parquet("voxforge_data/audio_features.parquet")

# %%
df.head(30)
# Out:
#                                filename  mean_freq_kHz  std_freq_kHz  \
# 0   robin-20070310-vf12/wav/vf12-34.wav       3.999961      2.309424
# 1   robin-20070310-vf12/wav/vf12-29.wav       4.000000      2.309454
# 2   robin-20070310-vf12/wav/vf12-24.wav       4.000000      2.309442
# 3   robin-20070310-vf12/wav/vf12-06.wav       4.000000      2.309460
# 4   robin-20070310-vf12/wav/vf12-38.wav       3.999964      2.309422
# 5   robin-20070310-vf12/wav/vf12-03.wav       4.000000      2.309478
# 6   robin-20070310-vf12/wav/vf12-40.wav       4.000000      2.309468
# 7   robin-20070310-vf12/wav/vf12-32.wav       4.000000      2.309434
# 8   robin-20070310-vf12/wav/vf12-09.wav       3.999960      2.309424
# 9   robin-20070310-vf12/wav/vf12-19.wav       4.000000      2.309475
# 10  robin-20070310-vf12/wav/vf12-31.wav       4.000000      2.309444
# 11  robin-20070310-vf12/wav/vf12-11.wav       4.000000      2.309457
# 12  robin-20070310-vf12/wav/vf12-36.wav       4.000000      2.309456
# 13  robin-20070310-vf12/wav/vf12-22.wav       4.000000      2.309456
# 14  robin-20070310-vf12/wav/vf12-15.wav       4.000000      2.309446
# 15  robin-20070310-vf12/wav/vf12-12.wav       4.000000      2.309452
# 16  robin-20070310-vf12/wav/vf12-16.wav       4.000000      2.309450
# 17  robin-20070310-vf12/wav/vf12-18.wav       4.000000      2.309459
# 18  robin-20070310-vf12/wav/vf12-28.wav       4.000000      2.309452
# 19  robin-20070310-vf12/wav/vf12-13.wav       4.000000      2.309478
# 20  robin-20070310-vf12/wav/vf12-02.wav       4.000000      2.309466
# 21  robin-20070310-vf12/wav/vf12-20.wav       4.000000      2.309482
# 22  robin-20070310-vf12/wav/vf12-21.wav       3.999950      2.309430
# 23  robin-20070310-vf12/wav/vf12-17.wav       4.000000      2.309459
# 24  robin-20070310-vf12/wav/vf12-39.wav       3.999961      2.309423
# 25  robin-20070310-vf12/wav/vf12-14.wav       4.000000      2.309461
# 26  robin-20070310-vf12/wav/vf12-26.wav       3.999958      2.309425
# 27  robin-20070310-vf12/wav/vf12-08.wav       4.000000      2.309454
# 28  robin-20070310-vf12/wav/vf12-35.wav       4.000000      2.309444
# 29  robin-20070310-vf12/wav/vf12-04.wav       4.000000      2.309477
#
#     median_freq_kHz  first_quantile_kHz  third_quantile_kHz   iqr_kHz  \
# 0          3.999961            1.999981            5.999942  3.999961
# 1          4.000000            2.000000            6.000000  4.000000
# 2          4.000000            2.000000            6.000000  4.000000
# 3          4.000000            2.000000            6.000000  4.000000
# 4          3.999964            1.999982            5.999946  3.999964
# 5          4.000000            2.000000            6.000000  4.000000
# 6          4.000000            2.000000            6.000000  4.000000
# 7          4.000000            2.000000            6.000000  4.000000
# 8          3.999960            1.999980            5.999940  3.999960
# 9          4.000000            2.000000            6.000000  4.000000
# 10         4.000000            2.000000            6.000000  4.000000
# 11         4.000000            2.000000            6.000000  4.000000
# 12         4.000000            2.000000            6.000000  4.000000
# 13         4.000000            2.000000            6.000000  4.000000
# 14         4.000000            2.000000            6.000000  4.000000
# 15         4.000000            2.000000            6.000000  4.000000
# 16         4.000000            2.000000            6.000000  4.000000
# 17         4.000000            2.000000            6.000000  4.000000
# 18         4.000000            2.000000            6.000000  4.000000
# 19         4.000000            2.000000            6.000000  4.000000
# 20         4.000000            2.000000            6.000000  4.000000
# 21         4.000000            2.000000            6.000000  4.000000
# 22         3.999950            1.999975            5.999926  3.999950
# 23         4.000000            2.000000            6.000000  4.000000
# 24         3.999961            1.999981            5.999942  3.999961
# 25         4.000000            2.000000            6.000000  4.000000
# 26         3.999958            1.999979            5.999937  3.999958
# 27         4.000000            2.000000            6.000000  4.000000
# 28         4.000000            2.000000            6.000000  4.000000
# 29         4.000000            2.000000            6.000000  4.000000
#
#     skewness   kurtosis  mode_freq_kHz  peak_freq_kHz  sp_entropy  flatness  \
# 0   4.289625  22.129724       0.596192       0.596192   13.797732  0.131873
# 1   4.468912  24.387798       0.518989       0.518989   13.671813  0.145211
# 2   4.768208  28.682903       0.522362       0.522362   13.983390  0.154861
# 3   4.288241  22.928845       0.165990       0.165990   13.383058  0.113975
# 4   4.437734  23.512740       0.327474       0.327474   14.031024  0.154637
# 5   5.017607  32.963787       0.439637       0.439637   12.726298  0.107020
# 6   6.397723  66.214303       0.586054       0.586054   13.176128  0.135573
# 7   5.048145  31.834775       0.513476       0.513476   14.314123  0.160156
# 8   5.452632  43.163835       0.550339       0.550339   13.920943  0.164200
# 9   4.593074  25.416905       0.348617       0.348617   13.171095  0.156655
# 10  4.824677  31.603137       0.589994       0.589994   13.983408  0.156968
# 11  4.321693  24.692713       0.556855       0.556855   13.432207  0.132498
# 12  5.332743  42.584270       0.573361       0.573361   13.614275  0.144000
# 13  5.233686  35.628444       0.327263       0.327263   13.476929  0.139330
# 14  4.577891  25.493957       0.161746       0.161746   13.771135  0.129965
# 15  4.866422  30.766843       0.558239       0.558239   13.556109  0.124499
# 16  7.850617  96.044536       0.540591       0.540591   13.593456  0.154139
# 17  4.970303  32.150537       0.552349       0.552349   13.467345  0.144268
# 18  4.807257  30.949539       0.310558       0.310558   13.870904  0.164818
# 19  4.607349  26.665901       0.182452       0.182452   13.038188  0.120922
# 20  4.056212  20.962259       0.528571       0.528571   13.224327  0.107518
# 21  5.781572  49.571028       0.522600       0.522600   12.908556  0.132524
# 22  4.345250  24.251306       0.561703       0.561703   13.332587  0.098262
# 23  5.097483  37.047038       0.550128       0.550128   13.321209  0.126924
# 24  5.635269  45.241124       0.551478       0.551478   13.694305  0.116112
# 25  4.732394  29.834335       0.565174       0.565174   13.428863  0.136446
# 26  4.635795  26.351644       0.554157       0.554157   13.801980  0.152641
# 27  4.548850  30.388284       0.548946       0.548946   13.693813  0.140988
# 28  5.139106  34.562699       0.519792       0.519792   13.856396  0.142195
# 29  4.921708  29.676569       0.309161       0.309161   12.811480  0.112246
#
#     centroid_kHz   modindx
# 0       1.104101  2.316162
# 1       1.173674  2.266816
# 2       1.182493  2.340302
# 3       1.056596  2.309039
# 4       1.212154  2.255088
# 5       0.936312  2.643977
# 6       1.121801  2.504664
# 7       1.210400  2.406112
# 8       1.255173  2.273952
# 9       1.203686  2.308686
# 10      1.217593  2.240745
# 11      1.071359  2.329112
# 12      1.211842  2.297070
# 13      1.123396  2.477886
# 14      1.101165  2.372528
# 15      1.063970  2.411671
# 16      1.160062  2.748696
# 17      1.151528  2.370084
# 18      1.346923  2.135429
# 19      1.110259  2.321964
# 20      1.030322  2.281553
# 21      1.112215  2.467130
# 22      1.013026  2.357703
# 23      1.050978  2.503726
# 24      1.050142  2.536766
# 25      1.133457  2.306177
# 26      1.197075  2.286484
# 27      1.178918  2.166870
# 28      1.153213  2.413381
# 29      0.971259  2.622283
