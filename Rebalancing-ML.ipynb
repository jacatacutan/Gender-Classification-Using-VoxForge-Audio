# %%
import pandas as pd
import numpy as np

from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_parquet("en_merged_df.parquet")

# %%
df["speaker_id"] = df["filename"].apply(lambda x: x.split("/wav/")[0])

# %%
unique_speakers = df["speaker_id"].unique()

# %%
train_speakers, temp_speakers = train_test_split(unique_speakers, test_size=0.3, random_state=42)
val_speakers, test_speakers = train_test_split(temp_speakers, test_size=0.5, random_state=42)

# %%
def assign_split(speaker_id):
    if speaker_id in train_speakers:
        return "train"
    elif speaker_id in val_speakers:
        return "val"
    elif speaker_id in test_speakers:
        return "test"
    else:
        return "unknown"  # safety net

df["split"] = df["speaker_id"].apply(assign_split)

# %%
df["split"].value_counts()
# Out:
# split
# train    31464
# val       7076
# test      6755
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df["gender_encoded"] = le.fit_transform(df["gender"])

# Confirm encoding
print("Label encoding map:", dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# Label encoding map: {'female': 0, 'male': 1}

# %%
feature_cols = [
    "mean_freq_kHz",     # Central tendency
    "std_freq_kHz",      # Spread of frequencies
    "skewness",          # Shape of spectrum
    "kurtosis",          # Shape of spectrum
    "mode_freq_kHz",     # Dominant frequency
    "sp_entropy",        # Spectral entropy
    "flatness",          # Spectral flatness (tonal vs. noise-like)
    "centroid_kHz",      # Spectral centroid (perceived brightness)
    "modindx"            # Modulation index (amplitude variation)
    "age_range"
]

# %%
X_train = df[df["split"] == "train"][feature_cols]
y_train = df[df["split"] == "train"]["gender_encoded"]

X_val = df[df["split"] == "val"][feature_cols]
y_val = df[df["split"] == "val"]["gender_encoded"]

X_test = df[df["split"] == "test"][feature_cols]
y_test = df[df["split"] == "test"]["gender_encoded"]

# %% [markdown]
# # ML

# %%
models = {
    "Dummy (Most Frequent)": DummyClassifier(strategy="most_frequent"),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Elastic Net (Logistic)": LogisticRegression(penalty="elasticnet", l1_ratio=0.5, solver="saga", max_iter=1000),
    "K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=5),
    "Naive Bayes": GaussianNB(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "Support Vector Machine": SVC(),
    "MLP Classifier": MLPClassifier(hidden_layer_sizes=(100,), max_iter=500),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric="logloss")
}

# %% [markdown]
# # SMOTE

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# Training, validation, and test evaluation loop with SMOTE
for name, model in models.items():
    print(f"\n=== {name} ===")

    pipeline = Pipeline([
        ("smote", SMOTE(random_state=42)),
        ("scaler", StandardScaler()),
        ("classifier", model)
    ])

    # Fit on training data
    pipeline.fit(X_train, y_train)

    # Train evaluation
    train_preds = pipeline.predict(X_train)
    train_acc = accuracy_score(y_train, train_preds)
    print(f"Train Accuracy: {train_acc:.4f}")
    print("Train Classification Report:")
    print(classification_report(y_train, train_preds, target_names=le.classes_))

    # Validation evaluation
    val_preds = pipeline.predict(X_val)
    val_acc = accuracy_score(y_val, val_preds)
    print(f"Validation Accuracy: {val_acc:.4f}")
    print("Validation Classification Report:")
    print(classification_report(y_val, val_preds, target_names=le.classes_))

    # Test evaluation
    test_preds = pipeline.predict(X_test)
    test_acc = accuracy_score(y_test, test_preds)
    print(f"Test Accuracy: {test_acc:.4f}")
    print("Test Classification Report:")
    print(classification_report(y_test, test_preds, target_names=le.classes_))

# Show summary table
results_df = pd.DataFrame(results)
print("\n=== Summary Table ===")
print(results_df.sort_values(by="Test Accuracy", ascending=False).reset_index(drop=True))
# Out:
# === Dummy (Most Frequent) ===
# Train Accuracy: 0.0698
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.13      2195
#         male       0.00      0.00      0.00     29269
#
#     accuracy                           0.07     31464
#    macro avg       0.03      0.50      0.07     31464
# weighted avg       0.00      0.07      0.01     31464
#
# Validation Accuracy: 0.0725
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.14       513
#         male       0.00      0.00      0.00      6563
#
#     accuracy                           0.07      7076
#    macro avg       0.04      0.50      0.07      7076
# weighted avg       0.01      0.07      0.01      7076
#
# Test Accuracy: 0.0487
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      1.00      0.09       329
#         male       0.00      0.00      0.00      6426
#
#     accuracy                           0.05      6755
#    macro avg       0.02      0.50      0.05      6755
# weighted avg       0.00      0.05      0.00      6755
#
#
# === Logistic Regression ===
# Train Accuracy: 0.5372
# Train Classification Report:
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#       female       0.09      0.61      0.16      2195
#         male       0.95      0.53      0.68     29269
#
#     accuracy                           0.54     31464
#    macro avg       0.52      0.57      0.42     31464
# weighted avg       0.89      0.54      0.64     31464
#
# Validation Accuracy: 0.5760
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.56      0.16       513
#         male       0.94      0.58      0.72      6563
#
#     accuracy                           0.58      7076
#    macro avg       0.52      0.57      0.44      7076
# weighted avg       0.88      0.58      0.68      7076
#
# Test Accuracy: 0.5504
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.57      0.11       329
#         male       0.96      0.55      0.70      6426
#
#     accuracy                           0.55      6755
#    macro avg       0.51      0.56      0.40      6755
# weighted avg       0.92      0.55      0.67      6755
#
#
# === Elastic Net (Logistic) ===
# Train Accuracy: 0.5372
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.61      0.16      2195
#         male       0.95      0.53      0.68     29269
#
#     accuracy                           0.54     31464
#    macro avg       0.52      0.57      0.42     31464
# weighted avg       0.89      0.54      0.64     31464
#
# Validation Accuracy: 0.5760
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.56      0.16       513
#         male       0.94      0.58      0.72      6563
#
#     accuracy                           0.58      7076
#    macro avg       0.52      0.57      0.44      7076
# weighted avg       0.88      0.58      0.68      7076
#
# Test Accuracy: 0.5503
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.57      0.11       329
#         male       0.96      0.55      0.70      6426
#
#     accuracy                           0.55      6755
#    macro avg       0.51      0.56      0.40      6755
# weighted avg       0.92      0.55      0.67      6755
#
#
# === K-Nearest Neighbors ===
# Train Accuracy: 0.8299
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.29      0.97      0.44      2195
#         male       1.00      0.82      0.90     29269
#
#     accuracy                           0.83     31464
#    macro avg       0.64      0.89      0.67     31464
# weighted avg       0.95      0.83      0.87     31464
#
# Validation Accuracy: 0.7442
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.16      0.61      0.26       513
#         male       0.96      0.75      0.85      6563
#
#     accuracy                           0.74      7076
#    macro avg       0.56      0.68      0.55      7076
# weighted avg       0.90      0.74      0.80      7076
#
# Test Accuracy: 0.7337
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.10      0.59      0.18       329
#         male       0.97      0.74      0.84      6426
#
#     accuracy                           0.73      6755
#    macro avg       0.54      0.66      0.51      6755
# weighted avg       0.93      0.73      0.81      6755
#
#
# === Naive Bayes ===
# Train Accuracy: 0.3413
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.78      0.14      2195
#         male       0.95      0.31      0.47     29269
#
#     accuracy                           0.34     31464
#    macro avg       0.51      0.54      0.30     31464
# weighted avg       0.89      0.34      0.44     31464
#
# Validation Accuracy: 0.3502
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.77      0.15       513
#         male       0.95      0.32      0.48      6563
#
#     accuracy                           0.35      7076
#    macro avg       0.51      0.54      0.31      7076
# weighted avg       0.88      0.35      0.45      7076
#
# Test Accuracy: 0.3161
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      0.70      0.09       329
#         male       0.95      0.30      0.45      6426
#
#     accuracy                           0.32      6755
#    macro avg       0.50      0.50      0.27      6755
# weighted avg       0.91      0.32      0.43      6755
#
#
# === Decision Tree ===
# Train Accuracy: 1.0000
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       1.00      1.00      1.00      2195
#         male       1.00      1.00      1.00     29269
#
#     accuracy                           1.00     31464
#    macro avg       1.00      1.00      1.00     31464
# weighted avg       1.00      1.00      1.00     31464
#
# Validation Accuracy: 0.7985
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.16      0.42      0.23       513
#         male       0.95      0.83      0.88      6563
#
#     accuracy                           0.80      7076
#    macro avg       0.55      0.62      0.56      7076
# weighted avg       0.89      0.80      0.84      7076
#
# Test Accuracy: 0.8036
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.11      0.44      0.18       329
#         male       0.97      0.82      0.89      6426
#
#     accuracy                           0.80      6755
#    macro avg       0.54      0.63      0.53      6755
# weighted avg       0.92      0.80      0.85      6755
#
#
# === Random Forest ===
# Train Accuracy: 1.0000
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       1.00      1.00      1.00      2195
#         male       1.00      1.00      1.00     29269
#
#     accuracy                           1.00     31464
#    macro avg       1.00      1.00      1.00     31464
# weighted avg       1.00      1.00      1.00     31464
#
# Validation Accuracy: 0.8680
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.25      0.40      0.31       513
#         male       0.95      0.90      0.93      6563
#
#     accuracy                           0.87      7076
#    macro avg       0.60      0.65      0.62      7076
# weighted avg       0.90      0.87      0.88      7076
#
# Test Accuracy: 0.8679
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.36      0.21       329
#         male       0.96      0.89      0.93      6426
#
#     accuracy                           0.87      6755
#    macro avg       0.56      0.63      0.57      6755
# weighted avg       0.92      0.87      0.89      6755
#
#
# === Gradient Boosting ===
# Train Accuracy: 0.7673
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.18      0.66      0.28      2195
#         male       0.97      0.78      0.86     29269
#
#     accuracy                           0.77     31464
#    macro avg       0.57      0.72      0.57     31464
# weighted avg       0.91      0.77      0.82     31464
#
# Validation Accuracy: 0.7701
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.17      0.57      0.26       513
#         male       0.96      0.79      0.86      6563
#
#     accuracy                           0.77      7076
#    macro avg       0.57      0.68      0.56      7076
# weighted avg       0.90      0.77      0.82      7076
#
# Test Accuracy: 0.7747
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.11      0.52      0.18       329
#         male       0.97      0.79      0.87      6426
#
#     accuracy                           0.77      6755
#    macro avg       0.54      0.66      0.53      6755
# weighted avg       0.93      0.77      0.84      6755
#
#
# === AdaBoost ===
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Train Accuracy: 0.6817
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.14      0.68      0.23      2195
#         male       0.97      0.68      0.80     29269
#
#     accuracy                           0.68     31464
#    macro avg       0.55      0.68      0.52     31464
# weighted avg       0.91      0.68      0.76     31464
#
# Validation Accuracy: 0.6844
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.61      0.22       513
#         male       0.96      0.69      0.80      6563
#
#     accuracy                           0.68      7076
#    macro avg       0.55      0.65      0.51      7076
# weighted avg       0.90      0.68      0.76      7076
#
# Test Accuracy: 0.6789
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.55      0.14       329
#         male       0.97      0.69      0.80      6426
#
#     accuracy                           0.68      6755
#    macro avg       0.53      0.62      0.47      6755
# weighted avg       0.92      0.68      0.77      6755
#
#
# === Support Vector Machine ===
# Train Accuracy: 0.6567
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.69      0.22      2195
#         male       0.97      0.65      0.78     29269
#
#     accuracy                           0.66     31464
#    macro avg       0.55      0.67      0.50     31464
# weighted avg       0.91      0.66      0.74     31464
#
# Validation Accuracy: 0.6637
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.62      0.21       513
#         male       0.96      0.67      0.79      6563
#
#     accuracy                           0.66      7076
#    macro avg       0.54      0.64      0.50      7076
# weighted avg       0.90      0.66      0.74      7076
#
# Test Accuracy: 0.6545
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.55      0.13       329
#         male       0.97      0.66      0.78      6426
#
#     accuracy                           0.65      6755
#    macro avg       0.52      0.60      0.46      6755
# weighted avg       0.92      0.65      0.75      6755
#
#
# === MLP Classifier ===
# Train Accuracy: 0.8089
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.22      0.70      0.34      2195
#         male       0.97      0.82      0.89     29269
#
#     accuracy                           0.81     31464
#    macro avg       0.60      0.76      0.61     31464
# weighted avg       0.92      0.81      0.85     31464
#
# Validation Accuracy: 0.7941
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.20      0.63      0.31       513
#         male       0.97      0.81      0.88      6563
#
#     accuracy                           0.79      7076
#    macro avg       0.58      0.72      0.59      7076
# weighted avg       0.91      0.79      0.84      7076
#
# Test Accuracy: 0.7842
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.11      0.47      0.18       329
#         male       0.97      0.80      0.88      6426
#
#     accuracy                           0.78      6755
#    macro avg       0.54      0.64      0.53      6755
# weighted avg       0.93      0.78      0.84      6755
#
#
# === XGBoost ===
# Train Accuracy: 0.9235
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.47      0.67      0.55      2195
#         male       0.97      0.94      0.96     29269
#
#     accuracy                           0.92     31464
#    macro avg       0.72      0.80      0.75     31464
# weighted avg       0.94      0.92      0.93     31464
#
# Validation Accuracy: 0.8746
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.26      0.38      0.31       513
#         male       0.95      0.91      0.93      6563
#
#     accuracy                           0.87      7076
#    macro avg       0.60      0.65      0.62      7076
# weighted avg       0.90      0.87      0.89      7076
#
# Test Accuracy: 0.8828
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.16      0.33      0.21       329
#         male       0.96      0.91      0.94      6426
#
#     accuracy                           0.88      6755
#    macro avg       0.56      0.62      0.58      6755
# weighted avg       0.92      0.88      0.90      6755
#
#
# === Summary Table ===
#                      Model  Train Accuracy  Validation Accuracy  Test Accuracy
# 0                  XGBoost        0.880594             0.828999       0.853442
# 1            Random Forest        0.980231             0.817552       0.830940
# 2            Decision Tree        0.980835             0.769927       0.800444
# 3        Gradient Boosting        0.775617             0.768937       0.777794
# 4      K-Nearest Neighbors        0.840770             0.749435       0.763879
# 5           MLP Classifier        0.724924             0.728378       0.730718
# 6                 AdaBoost        0.695398             0.693047       0.694301
# 7   Support Vector Machine        0.562738             0.547060       0.558401
# 8      Logistic Regression        0.442251             0.465235       0.418209
# 9   Elastic Net (Logistic)        0.441934             0.465093       0.417913
# 10             Naive Bayes        0.245741             0.258479       0.218209
# 11   Dummy (Most Frequent)        0.069762             0.072499       0.048705

# %% [markdown]
# # ADASYN

# %%
from imblearn.over_sampling import ADASYN
from imblearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# Training, validation, and test evaluation loop with ADASYN
for name, model in models.items():
    print(f"\n=== {name} ===")

    pipeline = Pipeline([
        ("adasyn", ADASYN(random_state=42)),
        ("scaler", StandardScaler()),
        ("classifier", model)
    ])

    # Fit on training data
    pipeline.fit(X_train, y_train)

    # Train evaluation
    train_preds = pipeline.predict(X_train)
    train_acc = accuracy_score(y_train, train_preds)
    print(f"Train Accuracy: {train_acc:.4f}")
    print("Train Classification Report:")
    print(classification_report(y_train, train_preds, target_names=le.classes_))

    # Validation evaluation
    val_preds = pipeline.predict(X_val)
    val_acc = accuracy_score(y_val, val_preds)
    print(f"Validation Accuracy: {val_acc:.4f}")
    print("Validation Classification Report:")
    print(classification_report(y_val, val_preds, target_names=le.classes_))

    # Test evaluation
    test_preds = pipeline.predict(X_test)
    test_acc = accuracy_score(y_test, test_preds)
    print(f"Test Accuracy: {test_acc:.4f}")
    print("Test Classification Report:")
    print(classification_report(y_test, test_preds, target_names=le.classes_))

# Show summary table
results_df = pd.DataFrame(results)
print("\n=== Summary Table ===")
print(results_df.sort_values(by="Test Accuracy", ascending=False).reset_index(drop=True))
# Out:
# === Dummy (Most Frequent) ===
# Train Accuracy: 0.0698
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.13      2195
#         male       0.00      0.00      0.00     29269
#
#     accuracy                           0.07     31464
#    macro avg       0.03      0.50      0.07     31464
# weighted avg       0.00      0.07      0.01     31464
#
# Validation Accuracy: 0.0725
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.14       513
#         male       0.00      0.00      0.00      6563
#
#     accuracy                           0.07      7076
#    macro avg       0.04      0.50      0.07      7076
# weighted avg       0.01      0.07      0.01      7076
#
# Test Accuracy: 0.0487
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      1.00      0.09       329
#         male       0.00      0.00      0.00      6426
#
#     accuracy                           0.05      6755
#    macro avg       0.02      0.50      0.05      6755
# weighted avg       0.00      0.05      0.00      6755
#
#
# === Logistic Regression ===
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Train Accuracy: 0.5297
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.62      0.15      2195
#         male       0.95      0.52      0.67     29269
#
#     accuracy                           0.53     31464
#    macro avg       0.52      0.57      0.41     31464
# weighted avg       0.89      0.53      0.64     31464
#
# Validation Accuracy: 0.5715
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.57      0.16       513
#         male       0.94      0.57      0.71      6563
#
#     accuracy                           0.57      7076
#    macro avg       0.52      0.57      0.44      7076
# weighted avg       0.88      0.57      0.67      7076
#
# Test Accuracy: 0.5436
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.56      0.11       329
#         male       0.96      0.54      0.69      6426
#
#     accuracy                           0.54      6755
#    macro avg       0.51      0.55      0.40      6755
# weighted avg       0.92      0.54      0.66      6755
#
#
# === Elastic Net (Logistic) ===
# Train Accuracy: 0.5297
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.62      0.15      2195
#         male       0.95      0.52      0.67     29269
#
#     accuracy                           0.53     31464
#    macro avg       0.52      0.57      0.41     31464
# weighted avg       0.89      0.53      0.64     31464
#
# Validation Accuracy: 0.5718
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.57      0.16       513
#         male       0.94      0.57      0.71      6563
#
#     accuracy                           0.57      7076
#    macro avg       0.52      0.57      0.44      7076
# weighted avg       0.88      0.57      0.67      7076
#
# Test Accuracy: 0.5436
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.56      0.11       329
#         male       0.96      0.54      0.69      6426
#
#     accuracy                           0.54      6755
#    macro avg       0.51      0.55      0.40      6755
# weighted avg       0.92      0.54      0.66      6755
#
#
# === K-Nearest Neighbors ===
# Train Accuracy: 0.8314
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.29      0.97      0.44      2195
#         male       1.00      0.82      0.90     29269
#
#     accuracy                           0.83     31464
#    macro avg       0.64      0.89      0.67     31464
# weighted avg       0.95      0.83      0.87     31464
#
# Validation Accuracy: 0.7415
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.16      0.59      0.25       513
#         male       0.96      0.75      0.84      6563
#
#     accuracy                           0.74      7076
#    macro avg       0.56      0.67      0.55      7076
# weighted avg       0.90      0.74      0.80      7076
#
# Test Accuracy: 0.7350
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.10      0.57      0.17       329
#         male       0.97      0.74      0.84      6426
#
#     accuracy                           0.74      6755
#    macro avg       0.54      0.66      0.51      6755
# weighted avg       0.93      0.74      0.81      6755
#
#
# === Naive Bayes ===
# Train Accuracy: 0.3380
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.78      0.14      2195
#         male       0.95      0.30      0.46     29269
#
#     accuracy                           0.34     31464
#    macro avg       0.51      0.54      0.30     31464
# weighted avg       0.89      0.34      0.44     31464
#
# Validation Accuracy: 0.3457
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.77      0.15       513
#         male       0.95      0.31      0.47      6563
#
#     accuracy                           0.35      7076
#    macro avg       0.51      0.54      0.31      7076
# weighted avg       0.88      0.35      0.45      7076
#
# Test Accuracy: 0.3149
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      0.71      0.09       329
#         male       0.95      0.29      0.45      6426
#
#     accuracy                           0.31      6755
#    macro avg       0.50      0.50      0.27      6755
# weighted avg       0.91      0.31      0.43      6755
#
#
# === Decision Tree ===
# Train Accuracy: 1.0000
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       1.00      1.00      1.00      2195
#         male       1.00      1.00      1.00     29269
#
#     accuracy                           1.00     31464
#    macro avg       1.00      1.00      1.00     31464
# weighted avg       1.00      1.00      1.00     31464
#
# Validation Accuracy: 0.7807
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.14      0.41      0.21       513
#         male       0.95      0.81      0.87      6563
#
#     accuracy                           0.78      7076
#    macro avg       0.54      0.61      0.54      7076
# weighted avg       0.89      0.78      0.82      7076
#
# Test Accuracy: 0.7925
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.11      0.47      0.18       329
#         male       0.97      0.81      0.88      6426
#
#     accuracy                           0.79      6755
#    macro avg       0.54      0.64      0.53      6755
# weighted avg       0.93      0.79      0.85      6755
#
#
# === Random Forest ===
# Train Accuracy: 1.0000
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       1.00      1.00      1.00      2195
#         male       1.00      1.00      1.00     29269
#
#     accuracy                           1.00     31464
#    macro avg       1.00      1.00      1.00     31464
# weighted avg       1.00      1.00      1.00     31464
#
# Validation Accuracy: 0.8639
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.24      0.41      0.30       513
#         male       0.95      0.90      0.92      6563
#
#     accuracy                           0.86      7076
#    macro avg       0.60      0.65      0.61      7076
# weighted avg       0.90      0.86      0.88      7076
#
# Test Accuracy: 0.8648
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.14      0.34      0.20       329
#         male       0.96      0.89      0.93      6426
#
#     accuracy                           0.86      6755
#    macro avg       0.55      0.61      0.56      6755
# weighted avg       0.92      0.86      0.89      6755
#
#
# === Gradient Boosting ===
# Train Accuracy: 0.7646
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.18      0.64      0.28      2195
#         male       0.97      0.77      0.86     29269
#
#     accuracy                           0.76     31464
#    macro avg       0.57      0.71      0.57     31464
# weighted avg       0.91      0.76      0.82     31464
#
# Validation Accuracy: 0.7668
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.17      0.55      0.25       513
#         male       0.96      0.78      0.86      6563
#
#     accuracy                           0.77      7076
#    macro avg       0.56      0.67      0.56      7076
# weighted avg       0.90      0.77      0.82      7076
#
# Test Accuracy: 0.7676
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.11      0.53      0.18       329
#         male       0.97      0.78      0.86      6426
#
#     accuracy                           0.77      6755
#    macro avg       0.54      0.66      0.52      6755
# weighted avg       0.93      0.77      0.83      6755
#
#
# === AdaBoost ===
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Train Accuracy: 0.6785
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.14      0.68      0.23      2195
#         male       0.97      0.68      0.80     29269
#
#     accuracy                           0.68     31464
#    macro avg       0.55      0.68      0.51     31464
# weighted avg       0.91      0.68      0.76     31464
#
# Validation Accuracy: 0.6830
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.59      0.21       513
#         male       0.96      0.69      0.80      6563
#
#     accuracy                           0.68      7076
#    macro avg       0.54      0.64      0.51      7076
# weighted avg       0.90      0.68      0.76      7076
#
# Test Accuracy: 0.6759
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.60      0.15       329
#         male       0.97      0.68      0.80      6426
#
#     accuracy                           0.68      6755
#    macro avg       0.53      0.64      0.48      6755
# weighted avg       0.93      0.68      0.77      6755
#
#
# === Support Vector Machine ===
# Train Accuracy: 0.6530
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.69      0.22      2195
#         male       0.97      0.65      0.78     29269
#
#     accuracy                           0.65     31464
#    macro avg       0.55      0.67      0.50     31464
# weighted avg       0.91      0.65      0.74     31464
#
# Validation Accuracy: 0.6614
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.62      0.21       513
#         male       0.96      0.66      0.78      6563
#
#     accuracy                           0.66      7076
#    macro avg       0.54      0.64      0.50      7076
# weighted avg       0.90      0.66      0.74      7076
#
# Test Accuracy: 0.6506
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      0.54      0.13       329
#         male       0.97      0.66      0.78      6426
#
#     accuracy                           0.65      6755
#    macro avg       0.52      0.60      0.46      6755
# weighted avg       0.92      0.65      0.75      6755
#
#
# === MLP Classifier ===
# Train Accuracy: 0.7728
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.20      0.74      0.31      2195
#         male       0.98      0.78      0.86     29269
#
#     accuracy                           0.77     31464
#    macro avg       0.59      0.76      0.59     31464
# weighted avg       0.92      0.77      0.83     31464
#
# Validation Accuracy: 0.7617
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.18      0.66      0.29       513
#         male       0.97      0.77      0.86      6563
#
#     accuracy                           0.76      7076
#    macro avg       0.58      0.72      0.57      7076
# weighted avg       0.91      0.76      0.82      7076
#
# Test Accuracy: 0.7557
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.10      0.53      0.17       329
#         male       0.97      0.77      0.86      6426
#
#     accuracy                           0.76      6755
#    macro avg       0.54      0.65      0.52      6755
# weighted avg       0.93      0.76      0.82      6755
#
#
# === XGBoost ===
# Train Accuracy: 0.9218
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.46      0.65      0.54      2195
#         male       0.97      0.94      0.96     29269
#
#     accuracy                           0.92     31464
#    macro avg       0.72      0.80      0.75     31464
# weighted avg       0.94      0.92      0.93     31464
#
# Validation Accuracy: 0.8749
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.25      0.37      0.30       513
#         male       0.95      0.91      0.93      6563
#
#     accuracy                           0.87      7076
#    macro avg       0.60      0.64      0.61      7076
# weighted avg       0.90      0.87      0.89      7076
#
# Test Accuracy: 0.8792
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.16      0.36      0.22       329
#         male       0.96      0.91      0.93      6426
#
#     accuracy                           0.88      6755
#    macro avg       0.56      0.63      0.58      6755
# weighted avg       0.93      0.88      0.90      6755
#
#
# === Summary Table ===
#                      Model  Train Accuracy  Validation Accuracy  Test Accuracy
# 0                  XGBoost        0.880594             0.828999       0.853442
# 1            Random Forest        0.980231             0.817552       0.830940
# 2            Decision Tree        0.980835             0.769927       0.800444
# 3        Gradient Boosting        0.775617             0.768937       0.777794
# 4      K-Nearest Neighbors        0.840770             0.749435       0.763879
# 5           MLP Classifier        0.724924             0.728378       0.730718
# 6                 AdaBoost        0.695398             0.693047       0.694301
# 7   Support Vector Machine        0.562738             0.547060       0.558401
# 8      Logistic Regression        0.442251             0.465235       0.418209
# 9   Elastic Net (Logistic)        0.441934             0.465093       0.417913
# 10             Naive Bayes        0.245741             0.258479       0.218209
# 11   Dummy (Most Frequent)        0.069762             0.072499       0.048705

# %% [markdown]
# # SMOTETonek

# %%
from imblearn.combine import SMOTETomek
from imblearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Store results
results = []

# Training, validation, and test evaluation loop with SMOTETomek
for name, model in models.items():
    print(f"\n=== {name} ===")

    pipeline = Pipeline([
        ("smotetomek", SMOTETomek(random_state=42)),
        ("scaler", StandardScaler()),
        ("classifier", model)
    ])

    # Fit on training data
    pipeline.fit(X_train, y_train)

    # Train evaluation
    train_preds = pipeline.predict(X_train)
    train_acc = accuracy_score(y_train, train_preds)
    print(f"Train Accuracy: {train_acc:.4f}")
    print("Train Classification Report:")
    print(classification_report(y_train, train_preds, target_names=le.classes_))

    # Validation evaluation
    val_preds = pipeline.predict(X_val)
    val_acc = accuracy_score(y_val, val_preds)
    print(f"Validation Accuracy: {val_acc:.4f}")
    print("Validation Classification Report:")
    print(classification_report(y_val, val_preds, target_names=le.classes_))

    # Test evaluation
    test_preds = pipeline.predict(X_test)
    test_acc = accuracy_score(y_test, test_preds)
    print(f"Test Accuracy: {test_acc:.4f}")
    print("Test Classification Report:")
    print(classification_report(y_test, test_preds, target_names=le.classes_))

    # Save results
    results.append({
        "Model": name,
        "Train Accuracy": train_acc,
        "Validation Accuracy": val_acc,
        "Test Accuracy": test_acc
    })

# Show summary table
results_df = pd.DataFrame(results)
print("\n=== Summary Table ===")
print(results_df.sort_values(by="Test Accuracy", ascending=False).reset_index(drop=True))
# Out:
# === Dummy (Most Frequent) ===
# Train Accuracy: 0.0698
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.13      2195
#         male       0.00      0.00      0.00     29269
#
#     accuracy                           0.07     31464
#    macro avg       0.03      0.50      0.07     31464
# weighted avg       0.00      0.07      0.01     31464
#
# Validation Accuracy: 0.0725
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.14       513
#         male       0.00      0.00      0.00      6563
#
#     accuracy                           0.07      7076
#    macro avg       0.04      0.50      0.07      7076
# weighted avg       0.01      0.07      0.01      7076
#
# Test Accuracy: 0.0487
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      1.00      0.09       329
#         male       0.00      0.00      0.00      6426
#
#     accuracy                           0.05      6755
#    macro avg       0.02      0.50      0.05      6755
# weighted avg       0.00      0.05      0.00      6755
#
#
# === Logistic Regression ===
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Train Accuracy: 0.5356
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.62      0.16      2195
#         male       0.95      0.53      0.68     29269
#
#     accuracy                           0.54     31464
#    macro avg       0.52      0.58      0.42     31464
# weighted avg       0.89      0.54      0.64     31464
#
# Validation Accuracy: 0.5733
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.55      0.16       513
#         male       0.94      0.57      0.71      6563
#
#     accuracy                           0.57      7076
#    macro avg       0.52      0.56      0.44      7076
# weighted avg       0.88      0.57      0.67      7076
#
# Test Accuracy: 0.5483
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.57      0.11       329
#         male       0.96      0.55      0.70      6426
#
#     accuracy                           0.55      6755
#    macro avg       0.51      0.56      0.40      6755
# weighted avg       0.92      0.55      0.67      6755
#
#
# === Elastic Net (Logistic) ===
# Train Accuracy: 0.5355
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.62      0.16      2195
#         male       0.95      0.53      0.68     29269
#
#     accuracy                           0.54     31464
#    macro avg       0.52      0.58      0.42     31464
# weighted avg       0.89      0.54      0.64     31464
#
# Validation Accuracy: 0.5732
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.55      0.16       513
#         male       0.94      0.57      0.71      6563
#
#     accuracy                           0.57      7076
#    macro avg       0.52      0.56      0.44      7076
# weighted avg       0.88      0.57      0.67      7076
#
# Test Accuracy: 0.5483
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.57      0.11       329
#         male       0.96      0.55      0.70      6426
#
#     accuracy                           0.55      6755
#    macro avg       0.51      0.56      0.40      6755
# weighted avg       0.92      0.55      0.67      6755
#
#
# === K-Nearest Neighbors ===
# Train Accuracy: 0.8245
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.28      0.96      0.43      2195
#         male       1.00      0.81      0.90     29269
#
#     accuracy                           0.82     31464
#    macro avg       0.64      0.89      0.66     31464
# weighted avg       0.95      0.82      0.86     31464
#
# Validation Accuracy: 0.7452
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.16      0.61      0.26       513
#         male       0.96      0.76      0.85      6563
#
#     accuracy                           0.75      7076
#    macro avg       0.56      0.68      0.55      7076
# weighted avg       0.90      0.75      0.80      7076
#
# Test Accuracy: 0.7326
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.10      0.58      0.17       329
#         male       0.97      0.74      0.84      6426
#
#     accuracy                           0.73      6755
#    macro avg       0.54      0.66      0.51      6755
# weighted avg       0.93      0.73      0.81      6755
#
#
# === Naive Bayes ===
# Train Accuracy: 0.3363
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.77      0.14      2195
#         male       0.95      0.30      0.46     29269
#
#     accuracy                           0.34     31464
#    macro avg       0.51      0.54      0.30     31464
# weighted avg       0.89      0.34      0.44     31464
#
# Validation Accuracy: 0.3479
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.78      0.15       513
#         male       0.95      0.31      0.47      6563
#
#     accuracy                           0.35      7076
#    macro avg       0.51      0.55      0.31      7076
# weighted avg       0.88      0.35      0.45      7076
#
# Test Accuracy: 0.3150
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      0.71      0.09       329
#         male       0.95      0.29      0.45      6426
#
#     accuracy                           0.32      6755
#    macro avg       0.50      0.50      0.27      6755
# weighted avg       0.91      0.32      0.43      6755
#
#
# === Decision Tree ===
# Train Accuracy: 0.9921
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.90      0.99      0.95      2195
#         male       1.00      0.99      1.00     29269
#
#     accuracy                           0.99     31464
#    macro avg       0.95      0.99      0.97     31464
# weighted avg       0.99      0.99      0.99     31464
#
# Validation Accuracy: 0.7941
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.41      0.23       513
#         male       0.95      0.82      0.88      6563
#
#     accuracy                           0.79      7076
#    macro avg       0.55      0.62      0.55      7076
# weighted avg       0.89      0.79      0.83      7076
#
# Test Accuracy: 0.7945
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.10      0.40      0.16       329
#         male       0.96      0.81      0.88      6426
#
#     accuracy                           0.79      6755
#    macro avg       0.53      0.61      0.52      6755
# weighted avg       0.92      0.79      0.85      6755
#
#
# === Random Forest ===
# Train Accuracy: 0.9939
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.92      0.99      0.96      2195
#         male       1.00      0.99      1.00     29269
#
#     accuracy                           0.99     31464
#    macro avg       0.96      0.99      0.98     31464
# weighted avg       0.99      0.99      0.99     31464
#
# Validation Accuracy: 0.8657
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.24      0.40      0.30       513
#         male       0.95      0.90      0.93      6563
#
#     accuracy                           0.87      7076
#    macro avg       0.60      0.65      0.61      7076
# weighted avg       0.90      0.87      0.88      7076
#
# Test Accuracy: 0.8703
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.36      0.21       329
#         male       0.96      0.90      0.93      6426
#
#     accuracy                           0.87      6755
#    macro avg       0.56      0.63      0.57      6755
# weighted avg       0.93      0.87      0.89      6755
#
#
# === Gradient Boosting ===
# Train Accuracy: 0.7655
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.18      0.67      0.28      2195
#         male       0.97      0.77      0.86     29269
#
#     accuracy                           0.77     31464
#    macro avg       0.57      0.72      0.57     31464
# weighted avg       0.91      0.77      0.82     31464
#
# Validation Accuracy: 0.7684
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.17      0.57      0.26       513
#         male       0.96      0.78      0.86      6563
#
#     accuracy                           0.77      7076
#    macro avg       0.57      0.68      0.56      7076
# weighted avg       0.90      0.77      0.82      7076
#
# Test Accuracy: 0.7708
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.11      0.55      0.19       329
#         male       0.97      0.78      0.87      6426
#
#     accuracy                           0.77      6755
#    macro avg       0.54      0.67      0.53      6755
# weighted avg       0.93      0.77      0.83      6755
#
#
# === AdaBoost ===
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Train Accuracy: 0.6880
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.14      0.67      0.23      2195
#         male       0.97      0.69      0.80     29269
#
#     accuracy                           0.69     31464
#    macro avg       0.55      0.68      0.52     31464
# weighted avg       0.91      0.69      0.76     31464
#
# Validation Accuracy: 0.6943
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.59      0.22       513
#         male       0.96      0.70      0.81      6563
#
#     accuracy                           0.69      7076
#    macro avg       0.55      0.65      0.51      7076
# weighted avg       0.90      0.69      0.77      7076
#
# Test Accuracy: 0.6885
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.58      0.15       329
#         male       0.97      0.69      0.81      6426
#
#     accuracy                           0.69      6755
#    macro avg       0.53      0.64      0.48      6755
# weighted avg       0.93      0.69      0.78      6755
#
#
# === Support Vector Machine ===
# Train Accuracy: 0.6535
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.69      0.22      2195
#         male       0.97      0.65      0.78     29269
#
#     accuracy                           0.65     31464
#    macro avg       0.55      0.67      0.50     31464
# weighted avg       0.91      0.65      0.74     31464
#
# Validation Accuracy: 0.6598
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.62      0.21       513
#         male       0.96      0.66      0.78      6563
#
#     accuracy                           0.66      7076
#    macro avg       0.54      0.64      0.50      7076
# weighted avg       0.90      0.66      0.74      7076
#
# Test Accuracy: 0.6511
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.54      0.13       329
#         male       0.97      0.66      0.78      6426
#
#     accuracy                           0.65      6755
#    macro avg       0.52      0.60      0.46      6755
# weighted avg       0.92      0.65      0.75      6755
#
#
# === MLP Classifier ===
# Train Accuracy: 0.8170
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.23      0.68      0.34      2195
#         male       0.97      0.83      0.89     29269
#
#     accuracy                           0.82     31464
#    macro avg       0.60      0.75      0.62     31464
# weighted avg       0.92      0.82      0.86     31464
#
# Validation Accuracy: 0.8020
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.20      0.57      0.29       513
#         male       0.96      0.82      0.88      6563
#
#     accuracy                           0.80      7076
#    macro avg       0.58      0.69      0.59      7076
# weighted avg       0.91      0.80      0.84      7076
#
# Test Accuracy: 0.7996
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.11      0.45      0.18       329
#         male       0.97      0.82      0.89      6426
#
#     accuracy                           0.80      6755
#    macro avg       0.54      0.63      0.53      6755
# weighted avg       0.93      0.80      0.85      6755
#
#
# === XGBoost ===
# Train Accuracy: 0.9205
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.45      0.69      0.55      2195
#         male       0.98      0.94      0.96     29269
#
#     accuracy                           0.92     31464
#    macro avg       0.71      0.81      0.75     31464
# weighted avg       0.94      0.92      0.93     31464
#
# Validation Accuracy: 0.8680
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.24      0.38      0.29       513
#         male       0.95      0.91      0.93      6563
#
#     accuracy                           0.87      7076
#    macro avg       0.59      0.64      0.61      7076
# weighted avg       0.90      0.87      0.88      7076
#
# Test Accuracy: 0.8791
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.17      0.37      0.23       329
#         male       0.97      0.91      0.93      6426
#
#     accuracy                           0.88      6755
#    macro avg       0.57      0.64      0.58      6755
# weighted avg       0.93      0.88      0.90      6755
#
#
# === Summary Table ===
#                      Model  Train Accuracy  Validation Accuracy  Test Accuracy
# 0                  XGBoost        0.920481             0.868005       0.879053
# 1            Random Forest        0.993866             0.865743       0.870318
# 2           MLP Classifier        0.816997             0.802007       0.799556
# 3            Decision Tree        0.992086             0.794093       0.794523
# 4        Gradient Boosting        0.765542             0.768372       0.770836
# 5      K-Nearest Neighbors        0.824466             0.745195       0.732642
# 6                 AdaBoost        0.687961             0.694319       0.688527
# 7   Support Vector Machine        0.653477             0.659836       0.651073
# 8      Logistic Regression        0.535596             0.573347       0.548335
# 9   Elastic Net (Logistic)        0.535469             0.573205       0.548335
# 10             Naive Bayes        0.336321             0.347937       0.315026
# 11   Dummy (Most Frequent)        0.069762             0.072499       0.048705

# %% [markdown]
# # Oversample

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Store results
results_over = []

for name, model in models.items():
    print(f"\n=== {name} (RandomOverSampler) ===")

    pipeline = Pipeline([
        ("oversample", RandomOverSampler(random_state=42)),
        ("scaler", StandardScaler()),
        ("classifier", model)
    ])

    pipeline.fit(X_train, y_train)

    train_preds = pipeline.predict(X_train)
    val_preds = pipeline.predict(X_val)
    test_preds = pipeline.predict(X_test)

    train_acc = accuracy_score(y_train, train_preds)
    val_acc = accuracy_score(y_val, val_preds)
    test_acc = accuracy_score(y_test, test_preds)

    print(f"Train Accuracy: {train_acc:.4f}")
    print("Train Classification Report:")
    print(classification_report(y_train, train_preds, target_names=le.classes_))

    print(f"Validation Accuracy: {val_acc:.4f}")
    print("Validation Classification Report:")
    print(classification_report(y_val, val_preds, target_names=le.classes_))

    print(f"Test Accuracy: {test_acc:.4f}")
    print("Test Classification Report:")
    print(classification_report(y_test, test_preds, target_names=le.classes_))

    results_over.append({
        "Model": name,
        "Train Accuracy": train_acc,
        "Validation Accuracy": val_acc,
        "Test Accuracy": test_acc
    })

results_over_df = pd.DataFrame(results_over)
print("\n=== RandomOverSampler Summary Table ===")
print(results_over_df.sort_values(by="Test Accuracy", ascending=False).reset_index(drop=True))
# Out:
# === Dummy (Most Frequent) (RandomOverSampler) ===
# Train Accuracy: 0.0698
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.13      2195
#         male       0.00      0.00      0.00     29269
#
#     accuracy                           0.07     31464
#    macro avg       0.03      0.50      0.07     31464
# weighted avg       0.00      0.07      0.01     31464
#
# Validation Accuracy: 0.0725
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.14       513
#         male       0.00      0.00      0.00      6563
#
#     accuracy                           0.07      7076
#    macro avg       0.04      0.50      0.07      7076
# weighted avg       0.01      0.07      0.01      7076
#
# Test Accuracy: 0.0487
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      1.00      0.09       329
#         male       0.00      0.00      0.00      6426
#
#     accuracy                           0.05      6755
#    macro avg       0.02      0.50      0.05      6755
# weighted avg       0.00      0.05      0.00      6755
#
#
# === Logistic Regression (RandomOverSampler) ===
# Train Accuracy: 0.5430
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.60      0.16      2195
#         male       0.95      0.54      0.69     29269
#
#     accuracy                           0.54     31464
#    macro avg       0.52      0.57      0.42     31464
# weighted avg       0.89      0.54      0.65     31464
#
# Validation Accuracy: 0.5786
# Validation Classification Report:
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#       female       0.09      0.55      0.16       513
#         male       0.94      0.58      0.72      6563
#
#     accuracy                           0.58      7076
#    macro avg       0.52      0.57      0.44      7076
# weighted avg       0.88      0.58      0.68      7076
#
# Test Accuracy: 0.5563
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.56      0.11       329
#         male       0.96      0.56      0.70      6426
#
#     accuracy                           0.56      6755
#    macro avg       0.51      0.56      0.41      6755
# weighted avg       0.92      0.56      0.68      6755
#
#
# === Elastic Net (Logistic) (RandomOverSampler) ===
# Train Accuracy: 0.5429
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.60      0.16      2195
#         male       0.95      0.54      0.69     29269
#
#     accuracy                           0.54     31464
#    macro avg       0.52      0.57      0.42     31464
# weighted avg       0.89      0.54      0.65     31464
#
# Validation Accuracy: 0.5783
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.55      0.16       513
#         male       0.94      0.58      0.72      6563
#
#     accuracy                           0.58      7076
#    macro avg       0.52      0.57      0.44      7076
# weighted avg       0.88      0.58      0.68      7076
#
# Test Accuracy: 0.5563
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.56      0.11       329
#         male       0.96      0.56      0.70      6426
#
#     accuracy                           0.56      6755
#    macro avg       0.51      0.56      0.41      6755
# weighted avg       0.92      0.56      0.68      6755
#
#
# === K-Nearest Neighbors (RandomOverSampler) ===
# Train Accuracy: 0.9073
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.43      1.00      0.60      2195
#         male       1.00      0.90      0.95     29269
#
#     accuracy                           0.91     31464
#    macro avg       0.71      0.95      0.77     31464
# weighted avg       0.96      0.91      0.92     31464
#
# Validation Accuracy: 0.8310
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.20      0.45      0.28       513
#         male       0.95      0.86      0.90      6563
#
#     accuracy                           0.83      7076
#    macro avg       0.58      0.66      0.59      7076
# weighted avg       0.90      0.83      0.86      7076
#
# Test Accuracy: 0.8314
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.42      0.19       329
#         male       0.97      0.85      0.91      6426
#
#     accuracy                           0.83      6755
#    macro avg       0.55      0.63      0.55      6755
# weighted avg       0.93      0.83      0.87      6755
#
#
# === Naive Bayes (RandomOverSampler) ===
# Train Accuracy: 0.2985
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.80      0.14      2195
#         male       0.95      0.26      0.41     29269
#
#     accuracy                           0.30     31464
#    macro avg       0.51      0.53      0.27     31464
# weighted avg       0.88      0.30      0.39     31464
#
# Validation Accuracy: 0.3129
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.83      0.15       513
#         male       0.95      0.27      0.42      6563
#
#     accuracy                           0.31      7076
#    macro avg       0.52      0.55      0.29      7076
# weighted avg       0.89      0.31      0.40      7076
#
# Test Accuracy: 0.2777
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      0.77      0.09       329
#         male       0.95      0.25      0.40      6426
#
#     accuracy                           0.28      6755
#    macro avg       0.50      0.51      0.25      6755
# weighted avg       0.91      0.28      0.38      6755
#
#
# === Decision Tree (RandomOverSampler) ===
# Train Accuracy: 1.0000
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       1.00      1.00      1.00      2195
#         male       1.00      1.00      1.00     29269
#
#     accuracy                           1.00     31464
#    macro avg       1.00      1.00      1.00     31464
# weighted avg       1.00      1.00      1.00     31464
#
# Validation Accuracy: 0.8981
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.27      0.23      0.25       513
#         male       0.94      0.95      0.95      6563
#
#     accuracy                           0.90      7076
#    macro avg       0.60      0.59      0.60      7076
# weighted avg       0.89      0.90      0.89      7076
#
# Test Accuracy: 0.9153
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.19      0.22      0.20       329
#         male       0.96      0.95      0.96      6426
#
#     accuracy                           0.92      6755
#    macro avg       0.57      0.59      0.58      6755
# weighted avg       0.92      0.92      0.92      6755
#
#
# === Random Forest (RandomOverSampler) ===
# Train Accuracy: 1.0000
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       1.00      1.00      1.00      2195
#         male       1.00      1.00      1.00     29269
#
#     accuracy                           1.00     31464
#    macro avg       1.00      1.00      1.00     31464
# weighted avg       1.00      1.00      1.00     31464
#
# Validation Accuracy: 0.9288
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.53      0.18      0.27       513
#         male       0.94      0.99      0.96      6563
#
#     accuracy                           0.93      7076
#    macro avg       0.73      0.58      0.62      7076
# weighted avg       0.91      0.93      0.91      7076
#
# Test Accuracy: 0.9458
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.39      0.20      0.27       329
#         male       0.96      0.98      0.97      6426
#
#     accuracy                           0.95      6755
#    macro avg       0.68      0.59      0.62      6755
# weighted avg       0.93      0.95      0.94      6755
#
#
# === Gradient Boosting (RandomOverSampler) ===
# Train Accuracy: 0.7184
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.18      0.83      0.29      2195
#         male       0.98      0.71      0.82     29269
#
#     accuracy                           0.72     31464
#    macro avg       0.58      0.77      0.56     31464
# weighted avg       0.93      0.72      0.79     31464
#
# Validation Accuracy: 0.7049
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.16      0.72      0.26       513
#         male       0.97      0.70      0.82      6563
#
#     accuracy                           0.70      7076
#    macro avg       0.56      0.71      0.54      7076
# weighted avg       0.91      0.70      0.78      7076
#
# Test Accuracy: 0.7053
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.11      0.71      0.19       329
#         male       0.98      0.70      0.82      6426
#
#     accuracy                           0.71      6755
#    macro avg       0.54      0.71      0.51      6755
# weighted avg       0.94      0.71      0.79      6755
#
#
# === AdaBoost (RandomOverSampler) ===
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Train Accuracy: 0.6706
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.76      0.24      2195
#         male       0.97      0.66      0.79     29269
#
#     accuracy                           0.67     31464
#    macro avg       0.56      0.71      0.52     31464
# weighted avg       0.92      0.67      0.75     31464
#
# Validation Accuracy: 0.6629
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.67      0.22       513
#         male       0.96      0.66      0.78      6563
#
#     accuracy                           0.66      7076
#    macro avg       0.55      0.67      0.50      7076
# weighted avg       0.90      0.66      0.74      7076
#
# Test Accuracy: 0.6604
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.10      0.72      0.17       329
#         male       0.98      0.66      0.79      6426
#
#     accuracy                           0.66      6755
#    macro avg       0.54      0.69      0.48      6755
# weighted avg       0.94      0.66      0.76      6755
#
#
# === Support Vector Machine (RandomOverSampler) ===
# Train Accuracy: 0.6483
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.14      0.78      0.24      2195
#         male       0.98      0.64      0.77     29269
#
#     accuracy                           0.65     31464
#    macro avg       0.56      0.71      0.50     31464
# weighted avg       0.92      0.65      0.73     31464
#
# Validation Accuracy: 0.6440
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.13      0.71      0.22       513
#         male       0.97      0.64      0.77      6563
#
#     accuracy                           0.64      7076
#    macro avg       0.55      0.67      0.50      7076
# weighted avg       0.91      0.64      0.73      7076
#
# Test Accuracy: 0.6296
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.65      0.15       329
#         male       0.97      0.63      0.76      6426
#
#     accuracy                           0.63      6755
#    macro avg       0.53      0.64      0.46      6755
# weighted avg       0.93      0.63      0.73      6755
#
#
# === MLP Classifier (RandomOverSampler) ===
# Train Accuracy: 0.7981
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.24      0.84      0.37      2195
#         male       0.99      0.79      0.88     29269
#
#     accuracy                           0.80     31464
#    macro avg       0.61      0.82      0.62     31464
# weighted avg       0.93      0.80      0.84     31464
#
# Validation Accuracy: 0.7791
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.21      0.73      0.32       513
#         male       0.97      0.78      0.87      6563
#
#     accuracy                           0.78      7076
#    macro avg       0.59      0.76      0.60      7076
# weighted avg       0.92      0.78      0.83      7076
#
# Test Accuracy: 0.7612
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.12      0.63      0.20       329
#         male       0.98      0.77      0.86      6426
#
#     accuracy                           0.76      6755
#    macro avg       0.55      0.70      0.53      6755
# weighted avg       0.93      0.76      0.83      6755
#
#
# === XGBoost (RandomOverSampler) ===
# Train Accuracy: 0.9142
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.45      0.99      0.62      2195
#         male       1.00      0.91      0.95     29269
#
#     accuracy                           0.91     31464
#    macro avg       0.72      0.95      0.78     31464
# weighted avg       0.96      0.91      0.93     31464
#
# Validation Accuracy: 0.8624
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.27      0.54      0.36       513
#         male       0.96      0.89      0.92      6563
#
#     accuracy                           0.86      7076
#    macro avg       0.62      0.71      0.64      7076
# weighted avg       0.91      0.86      0.88      7076
#
# Test Accuracy: 0.8511
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.45      0.23       329
#         male       0.97      0.87      0.92      6426
#
#     accuracy                           0.85      6755
#    macro avg       0.56      0.66      0.57      6755
# weighted avg       0.93      0.85      0.88      6755
#
#
# === RandomOverSampler Summary Table ===
#                      Model  Train Accuracy  Validation Accuracy  Test Accuracy
# 0            Random Forest        1.000000             0.928773       0.945818
# 1            Decision Tree        1.000000             0.898106       0.915322
# 2                  XGBoost        0.914219             0.862352       0.851073
# 3      K-Nearest Neighbors        0.907323             0.830978       0.831384
# 4           MLP Classifier        0.798055             0.779112       0.761214
# 5        Gradient Boosting        0.718377             0.704918       0.705255
# 6                 AdaBoost        0.670608             0.662945       0.660400
# 7   Support Vector Machine        0.648296             0.644008       0.629608
# 8      Logistic Regression        0.543002             0.578575       0.556329
# 9   Elastic Net (Logistic)        0.542906             0.578293       0.556329
# 10             Naive Bayes        0.298532             0.312889       0.277720
# 11   Dummy (Most Frequent)        0.069762             0.072499       0.048705

# %% [markdown]
# # Undersample

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Store results
results_under = []

for name, model in models.items():
    print(f"\n=== {name} (RandomUnderSampler) ===")

    pipeline = Pipeline([
        ("undersample", RandomUnderSampler(random_state=42)),
        ("scaler", StandardScaler()),
        ("classifier", model)
    ])

    pipeline.fit(X_train, y_train)

    train_preds = pipeline.predict(X_train)
    val_preds = pipeline.predict(X_val)
    test_preds = pipeline.predict(X_test)

    train_acc = accuracy_score(y_train, train_preds)
    val_acc = accuracy_score(y_val, val_preds)
    test_acc = accuracy_score(y_test, test_preds)

    print(f"Train Accuracy: {train_acc:.4f}")
    print("Train Classification Report:")
    print(classification_report(y_train, train_preds, target_names=le.classes_))

    print(f"Validation Accuracy: {val_acc:.4f}")
    print("Validation Classification Report:")
    print(classification_report(y_val, val_preds, target_names=le.classes_))

    print(f"Test Accuracy: {test_acc:.4f}")
    print("Test Classification Report:")
    print(classification_report(y_test, test_preds, target_names=le.classes_))

    results_under.append({
        "Model": name,
        "Train Accuracy": train_acc,
        "Validation Accuracy": val_acc,
        "Test Accuracy": test_acc
    })

results_under_df = pd.DataFrame(results_under)
print("\n=== RandomUnderSampler Summary Table ===")
print(results_under_df.sort_values(by="Test Accuracy", ascending=False).reset_index(drop=True))
# Out:
# === Dummy (Most Frequent) (RandomUnderSampler) ===
# Train Accuracy: 0.0698
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.13      2195
#         male       0.00      0.00      0.00     29269
#
#     accuracy                           0.07     31464
#    macro avg       0.03      0.50      0.07     31464
# weighted avg       0.00      0.07      0.01     31464
#
# Validation Accuracy: 0.0725
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      1.00      0.14       513
#         male       0.00      0.00      0.00      6563
#
#     accuracy                           0.07      7076
#    macro avg       0.04      0.50      0.07      7076
# weighted avg       0.01      0.07      0.01      7076
#
# Test Accuracy: 0.0487
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      1.00      0.09       329
#         male       0.00      0.00      0.00      6426
#
#     accuracy                           0.05      6755
#    macro avg       0.02      0.50      0.05      6755
# weighted avg       0.00      0.05      0.00      6755
#
#
# === Logistic Regression (RandomUnderSampler) ===
# Train Accuracy: 0.5329
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.62      0.16      2195
#         male       0.95      0.53      0.68     29269
#
#     accuracy                           0.53     31464
#    macro avg       0.52      0.57      0.42     31464
# weighted avg       0.89      0.53      0.64     31464
#
# Validation Accuracy: 0.5718
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.55      0.16       513
#         male       0.94      0.57      0.71      6563
#
#     accuracy                           0.57      7076
#    macro avg       0.52      0.56      0.44      7076
# weighted avg       0.88      0.57      0.67      7076
#
# Test Accuracy: 0.5432
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.56      0.11       329
#         male       0.96      0.54      0.69      6426
#
#     accuracy                           0.54      6755
#    macro avg       0.51      0.55      0.40      6755
# weighted avg       0.92      0.54      0.66      6755
#
#
# === Elastic Net (Logistic) (RandomUnderSampler) ===
# Train Accuracy: 0.5328
# Train Classification Report:
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#       female       0.09      0.62      0.16      2195
#         male       0.95      0.53      0.68     29269
#
#     accuracy                           0.53     31464
#    macro avg       0.52      0.57      0.42     31464
# weighted avg       0.89      0.53      0.64     31464
#
# Validation Accuracy: 0.5718
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.55      0.16       513
#         male       0.94      0.57      0.71      6563
#
#     accuracy                           0.57      7076
#    macro avg       0.52      0.56      0.43      7076
# weighted avg       0.88      0.57      0.67      7076
#
# Test Accuracy: 0.5433
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.56      0.11       329
#         male       0.96      0.54      0.69      6426
#
#     accuracy                           0.54      6755
#    macro avg       0.51      0.55      0.40      6755
# weighted avg       0.92      0.54      0.66      6755
#
#
# === K-Nearest Neighbors (RandomUnderSampler) ===
# Train Accuracy: 0.6610
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.85      0.26      2195
#         male       0.98      0.65      0.78     29269
#
#     accuracy                           0.66     31464
#    macro avg       0.57      0.75      0.52     31464
# weighted avg       0.92      0.66      0.74     31464
#
# Validation Accuracy: 0.6495
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.14      0.73      0.23       513
#         male       0.97      0.64      0.77      6563
#
#     accuracy                           0.65      7076
#    macro avg       0.55      0.68      0.50      7076
# weighted avg       0.91      0.65      0.73      7076
#
# Test Accuracy: 0.6370
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.66      0.15       329
#         male       0.97      0.64      0.77      6426
#
#     accuracy                           0.64      6755
#    macro avg       0.53      0.65      0.46      6755
# weighted avg       0.93      0.64      0.74      6755
#
#
# === Naive Bayes (RandomUnderSampler) ===
# Train Accuracy: 0.2797
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.07      0.82      0.14      2195
#         male       0.95      0.24      0.38     29269
#
#     accuracy                           0.28     31464
#    macro avg       0.51      0.53      0.26     31464
# weighted avg       0.89      0.28      0.36     31464
#
# Validation Accuracy: 0.2947
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.08      0.85      0.15       513
#         male       0.96      0.25      0.40      6563
#
#     accuracy                           0.29      7076
#    macro avg       0.52      0.55      0.27      7076
# weighted avg       0.89      0.29      0.38      7076
#
# Test Accuracy: 0.2629
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.05      0.80      0.10       329
#         male       0.96      0.24      0.38      6426
#
#     accuracy                           0.26      6755
#    macro avg       0.50      0.52      0.24      6755
# weighted avg       0.91      0.26      0.36      6755
#
#
# === Decision Tree (RandomUnderSampler) ===
# Train Accuracy: 0.7412
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.21      1.00      0.35      2195
#         male       1.00      0.72      0.84     29269
#
#     accuracy                           0.74     31464
#    macro avg       0.61      0.86      0.59     31464
# weighted avg       0.95      0.74      0.80     31464
#
# Validation Accuracy: 0.6993
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.65      0.24       513
#         male       0.96      0.70      0.81      6563
#
#     accuracy                           0.70      7076
#    macro avg       0.55      0.68      0.53      7076
# weighted avg       0.90      0.70      0.77      7076
#
# Test Accuracy: 0.6878
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.62      0.16       329
#         male       0.97      0.69      0.81      6426
#
#     accuracy                           0.69      6755
#    macro avg       0.53      0.65      0.48      6755
# weighted avg       0.93      0.69      0.78      6755
#
#
# === Random Forest (RandomUnderSampler) ===
# Train Accuracy: 0.7910
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.25      1.00      0.40      2195
#         male       1.00      0.78      0.87     29269
#
#     accuracy                           0.79     31464
#    macro avg       0.63      0.89      0.64     31464
# weighted avg       0.95      0.79      0.84     31464
#
# Validation Accuracy: 0.7623
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.19      0.71      0.30       513
#         male       0.97      0.77      0.86      6563
#
#     accuracy                           0.76      7076
#    macro avg       0.58      0.74      0.58      7076
# weighted avg       0.92      0.76      0.82      7076
#
# Test Accuracy: 0.7511
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.12      0.67      0.21       329
#         male       0.98      0.76      0.85      6426
#
#     accuracy                           0.75      6755
#    macro avg       0.55      0.71      0.53      6755
# weighted avg       0.94      0.75      0.82      6755
#
#
# === Gradient Boosting (RandomUnderSampler) ===
# Train Accuracy: 0.6930
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.17      0.85      0.28      2195
#         male       0.98      0.68      0.81     29269
#
#     accuracy                           0.69     31464
#    macro avg       0.57      0.76      0.54     31464
# weighted avg       0.93      0.69      0.77     31464
#
# Validation Accuracy: 0.6832
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.73      0.25       513
#         male       0.97      0.68      0.80      6563
#
#     accuracy                           0.68      7076
#    macro avg       0.56      0.71      0.53      7076
# weighted avg       0.91      0.68      0.76      7076
#
# Test Accuracy: 0.6839
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.11      0.75      0.19       329
#         male       0.98      0.68      0.80      6426
#
#     accuracy                           0.68      6755
#    macro avg       0.54      0.72      0.50      6755
# weighted avg       0.94      0.68      0.77      6755
#
#
# === AdaBoost (RandomUnderSampler) ===
# /home/jacatacutan-wsl/miniforge3/envs/colab/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Train Accuracy: 0.6738
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.75      0.24      2195
#         male       0.97      0.67      0.79     29269
#
#     accuracy                           0.67     31464
#    macro avg       0.56      0.71      0.52     31464
# weighted avg       0.92      0.67      0.75     31464
#
# Validation Accuracy: 0.6759
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.14      0.69      0.24       513
#         male       0.97      0.67      0.79      6563
#
#     accuracy                           0.68      7076
#    macro avg       0.55      0.68      0.52      7076
# weighted avg       0.91      0.68      0.75      7076
#
# Test Accuracy: 0.6691
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.09      0.66      0.16       329
#         male       0.97      0.67      0.79      6426
#
#     accuracy                           0.67      6755
#    macro avg       0.53      0.67      0.48      6755
# weighted avg       0.93      0.67      0.76      6755
#
#
# === Support Vector Machine (RandomUnderSampler) ===
# Train Accuracy: 0.4927
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.10      0.81      0.18      2195
#         male       0.97      0.47      0.63     29269
#
#     accuracy                           0.49     31464
#    macro avg       0.54      0.64      0.41     31464
# weighted avg       0.91      0.49      0.60     31464
#
# Validation Accuracy: 0.5024
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.10      0.73      0.18       513
#         male       0.96      0.48      0.64      6563
#
#     accuracy                           0.50      7076
#    macro avg       0.53      0.61      0.41      7076
# weighted avg       0.90      0.50      0.61      7076
#
# Test Accuracy: 0.4717
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.06      0.67      0.11       329
#         male       0.96      0.46      0.62      6426
#
#     accuracy                           0.47      6755
#    macro avg       0.51      0.56      0.37      6755
# weighted avg       0.92      0.47      0.60      6755
#
#
# === MLP Classifier (RandomUnderSampler) ===
# Train Accuracy: 0.6932
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.16      0.80      0.27      2195
#         male       0.98      0.69      0.81     29269
#
#     accuracy                           0.69     31464
#    macro avg       0.57      0.74      0.54     31464
# weighted avg       0.92      0.69      0.77     31464
#
# Validation Accuracy: 0.6930
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.15      0.72      0.25       513
#         male       0.97      0.69      0.81      6563
#
#     accuracy                           0.69      7076
#    macro avg       0.56      0.71      0.53      7076
# weighted avg       0.91      0.69      0.77      7076
#
# Test Accuracy: 0.6816
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.10      0.72      0.18       329
#         male       0.98      0.68      0.80      6426
#
#     accuracy                           0.68      6755
#    macro avg       0.54      0.70      0.49      6755
# weighted avg       0.94      0.68      0.77      6755
#
#
# === XGBoost (RandomUnderSampler) ===
# Train Accuracy: 0.7714
# Train Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.23      0.99      0.38      2195
#         male       1.00      0.76      0.86     29269
#
#     accuracy                           0.77     31464
#    macro avg       0.62      0.87      0.62     31464
# weighted avg       0.95      0.77      0.83     31464
#
# Validation Accuracy: 0.7415
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.18      0.74      0.29       513
#         male       0.97      0.74      0.84      6563
#
#     accuracy                           0.74      7076
#    macro avg       0.58      0.74      0.57      7076
# weighted avg       0.92      0.74      0.80      7076
#
# Test Accuracy: 0.7294
# Test Classification Report:
#               precision    recall  f1-score   support
#
#       female       0.12      0.70      0.20       329
#         male       0.98      0.73      0.84      6426
#
#     accuracy                           0.73      6755
#    macro avg       0.55      0.72      0.52      6755
# weighted avg       0.94      0.73      0.81      6755
#
#
# === RandomUnderSampler Summary Table ===
#                      Model  Train Accuracy  Validation Accuracy  Test Accuracy
# 0            Random Forest        0.790999             0.762295       0.751147
# 1                  XGBoost        0.771421             0.741521       0.729386
# 2            Decision Tree        0.741228             0.699265       0.687787
# 3        Gradient Boosting        0.693046             0.683154       0.683938
# 4           MLP Classifier        0.693237             0.693047       0.681569
# 5                 AdaBoost        0.673754             0.675947       0.669134
# 6      K-Nearest Neighbors        0.661009             0.649520       0.637010
# 7   Elastic Net (Logistic)        0.532768             0.571792       0.543301
# 8      Logistic Regression        0.532927             0.571792       0.543153
# 9   Support Vector Machine        0.492722             0.502402       0.471651
# 10             Naive Bayes        0.279685             0.294658       0.262916
# 11   Dummy (Most Frequent)        0.069762             0.072499       0.048705
